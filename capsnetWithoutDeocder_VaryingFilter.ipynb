# %% [markdown]
# # Capsule Network Implementation
#
#  Experiment with Filters & kernels

# %% [markdown]
# Author: Gyanendar Manohar
#
# Date: 20/03/2022

# %% [markdown]
# Referance:
#
# * Code adapted from https://github.com/XifengGuo/CapsNet-Keras/blob/master/capsulenet.py
#
# * Author: Xifeng Guo, E-mail: guoxifeng1990@163.com, Github: https://github.com/XifengGuo/CapsNet-Keras

# %% [markdown]
# Details:
#
# Architure similar to present in the original paper for MINST dataset
#
# 32 Primary Capusle, 16 dimension output vector
#
#
# The decoder part is acts as regularizer which prevent overfitting during training of the newtork.
#
# There is no decoder part here which has been removed to make training faster.
#
# Loss of capsule network is margin loss + alpha * reconsutruction loss
# As decoder network is not present, only margin loss is considered

# %% [markdown]
# # Headers

# %%
import os
import random
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import tensorflow.keras.backend as K
from tensorflow.keras import initializers, layers
from sklearn.metrics import confusion_matrix
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split



print(tf.__version__)
# Out:
# Using TensorFlow backend.
# 2.7.0

# %% [markdown]
# # Set Seed

# %%
#Set Seed for random number generation
def set_seed(seed = 100):
  tf.random.set_seed(seed)
  np.random.seed(seed)
  random.seed(seed)

# %% [markdown]
# # CapsNet

# %%
class Length(layers.Layer):
    """
    Compute the length of vectors. This is used to compute a Tensor that has the same shape with y_true in margin_loss.
    Using this layer as model's output can directly predict labels by using `y_pred = np.argmax(model.predict(x), 1)`
    inputs: shape=[None, num_vectors, dim_vector]
    output: shape=[None, num_vectors]
    """
    def call(self, inputs, **kwargs):
        return tf.sqrt(tf.reduce_sum(tf.square(inputs), -1) + K.epsilon())

    def compute_output_shape(self, input_shape):
        return input_shape[:-1]

    def get_config(self):
        config = super(Length, self).get_config()
        return config


def squash(vectors, axis=-1):
    """
    Vector length is treated as probability which should lies between 0 and 1. This
    function brings the vector length in the range of 0 and 1
    @param vectors: vectors to be squashed, N-dim tensor
    @param axis: the axis to squash
    @return: a Tensor with same shape as input vectors
    """
    s_squared_norm = tf.reduce_sum(tf.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors


class CapsuleLayer(layers.Layer):
    """
    The capsule layer. It is similar to Dense layer. Dense layer has `in_num` inputs, each is a scalar, the output of the
    neuron from the former layer, and it has `out_num` output neurons. CapsuleLayer just expand the output of the neuron
    from scalar to vector. So its input shape = [None, input_num_capsule, input_dim_capsule] and output shape = \
    [None, num_capsule, dim_capsule]. For Dense Layer, input_dim_capsule = dim_capsule = 1.
    @param num_capsule: number of capsules in this layer
    @param dim_capsule: dimension of the output vectors of the capsules in this layer
    @param routings: number of iterations for the routing algorithm
    """
    def __init__(self, num_capsule, dim_capsule, routings=3,
                 kernel_initializer='glorot_uniform',
                 **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.kernel_initializer = initializers.get(kernel_initializer)

    def build(self, input_shape):
        assert len(input_shape) >= 3, "The input Tensor should have shape=[None, input_num_capsule, input_dim_capsule]"
        self.input_num_capsule = input_shape[1]
        self.input_dim_capsule = input_shape[2]

        # Transform matrix, from each input capsule to each output capsule, there's a unique weight as in Dense layer.
        self.W = self.add_weight(shape=[self.num_capsule, self.input_num_capsule,
                                        self.dim_capsule, self.input_dim_capsule],
                                 initializer=self.kernel_initializer,
                                 name='W')

        self.built = True

    def call(self, inputs, training=None):
        # inputs.shape=[None, input_num_capsule, input_dim_capsule]
        # inputs_expand.shape=[None, 1, input_num_capsule, input_dim_capsule, 1]
        inputs_expand = tf.expand_dims(tf.expand_dims(inputs, 1), -1)

        # Replicate num_capsule dimension to prepare being multiplied by W
        # inputs_tiled.shape=[None, num_capsule, input_num_capsule, input_dim_capsule, 1]
        inputs_tiled = tf.tile(inputs_expand, [1, self.num_capsule, 1, 1, 1])

        # Compute `inputs * W` by scanning inputs_tiled on dimension 0.
        # W.shape=[num_capsule, input_num_capsule, dim_capsule, input_dim_capsule]
        # x.shape=[num_capsule, input_num_capsule, input_dim_capsule, 1]
        # Regard the first two dimensions as `batch` dimension, then
        # matmul(W, x): [..., dim_capsule, input_dim_capsule] x [..., input_dim_capsule, 1] -> [..., dim_capsule, 1].
        # inputs_hat.shape = [None, num_capsule, input_num_capsule, dim_capsule]
        inputs_hat = tf.squeeze(tf.map_fn(lambda x: tf.matmul(self.W, x), elems=inputs_tiled))

        # Begin: Routing algorithm ---------------------------------------------------------------------#
        # The prior for coupling coefficient, initialized as zeros.
        # b.shape = [None, self.num_capsule, 1, self.input_num_capsule].
        b = tf.zeros(shape=[inputs.shape[0], self.num_capsule, 1, self.input_num_capsule])

        assert self.routings > 0, 'The routings should be > 0.'
        for i in range(self.routings):
            # c.shape=[batch_size, num_capsule, 1, input_num_capsule]
            c = tf.nn.softmax(b, axis=1)

            # c.shape = [batch_size, num_capsule, 1, input_num_capsule]
            # inputs_hat.shape=[None, num_capsule, input_num_capsule, dim_capsule]
            # The first two dimensions as `batch` dimension,
            # then matmal: [..., 1, input_num_capsule] x [..., input_num_capsule, dim_capsule] -> [..., 1, dim_capsule].
            # outputs.shape=[None, num_capsule, 1, dim_capsule]
            outputs = squash(tf.matmul(c, inputs_hat))  # [None, 10, 1, 16]

            if i < self.routings - 1:
                # outputs.shape =  [None, num_capsule, 1, dim_capsule]
                # inputs_hat.shape=[None, num_capsule, input_num_capsule, dim_capsule]
                # The first two dimensions as `batch` dimension, then
                # matmal:[..., 1, dim_capsule] x [..., input_num_capsule, dim_capsule]^T -> [..., 1, input_num_capsule].
                # b.shape=[batch_size, num_capsule, 1, input_num_capsule]
                b += tf.matmul(outputs, inputs_hat, transpose_b=True)
        # End: Routing algorithm -----------------------------------------------------------------------#

        return tf.squeeze(outputs)

    def compute_output_shape(self, input_shape):
        return tuple([None, self.num_capsule, self.dim_capsule])

    def get_config(self):
        config = {
            'num_capsule': self.num_capsule,
            'dim_capsule': self.dim_capsule,
            'routings': self.routings
        }
        base_config = super(CapsuleLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))


def PrimaryCap(inputs, dim_capsule, n_channels, kernel_size, strides, padding):
    """
    Apply Conv2D `n_channels` times and concatenate all capsules
    @param inputs: 4D tensor, shape=[None, width, height, channels]
    @param dim_capsule: the dim of the output vector of capsule
    @param n_channels: the number of types of capsules
    @return: output tensor, shape=[None, num_capsule, dim_capsule]
    """
    output = layers.Conv2D(filters = dim_capsule*n_channels, 
                           kernel_size = kernel_size, 
                           strides = strides, 
                           padding = padding,
                           name='primarycap_conv2d')(inputs)
    outputs = layers.Reshape(target_shape = [-1, dim_capsule], 
                             name = 'primarycap_reshape')(output)
                             
    return layers.Lambda(squash, name='primarycap_squash')(outputs)

# %%
K.set_image_data_format('channels_last')

# %%
class CapsuleNet:
  @staticmethod
  def build(input_shape,number_of_class,routing_count,batch_size,
            n_channels = 32,dim_capsule=16,primary_caps_dim = 8,
            kernels=[9],filters=[256],strides=[1],
            multi_level_feature_extraction = False):
    
   

   #@param input_shape: data shape, 3d, [width, height, channels]
   #@param number_of_class: number of classes
   #@param routing_count: number of routing iterations
   #@param batch_size: size of batch
   #@return: Two Keras Models, the first one used for training, and the second one for evaluation.
   #        `eval_model` can also be used for training.
   

   input = layers.Input(shape=input_shape, batch_size=batch_size)  

  
   #THis part if for experimentation
   if multi_level_feature_extraction == True:
      conv1_1 = layers.Conv2D(filters=128, 
                             kernel_size=9,                              
                             padding='valid', 
                             activation='relu')(input)
      
      conv2_1 = layers.Conv2D(filters=128, 
                             kernel_size=9,                              
                             padding='valid', 
                             activation='relu')(input)
      
      conv2_2 = layers.Conv2D(filters=128, 
                             kernel_size=5,                              
                             padding='valid', 
                             activation='relu')(conv1_1)
      print(f"conv2_2:{conv2_2.shape}")                             
                                                                   
      conv = layers.concatenate([conv1_1, conv2_1])
   else:
      # Basic core model
      for index in range(len(kernels)):
          if index == 0 :
            conv = layers.Conv2D(filters=filters[index], 
                                kernel_size=kernels[index], 
                                strides=strides[index], 
                                padding='valid', 
                                activation='relu', 
                                name='conv'+str(index))(input)
          else:
            conv = layers.Conv2D(filters=filters[index], 
                                kernel_size=kernels[index], 
                                strides=strides[index], 
                                padding='valid', 
                                activation='relu', 
                                name='conv'+str(index))(conv)
   n_channels = filters[-1]//primary_caps_dim
   primary_capsule = PrimaryCap(conv, primary_caps_dim, n_channels, kernels[-1], strides[-1], 'valid')
   
   digitcaps = CapsuleLayer(num_capsule=number_of_class, 
                             dim_capsule=dim_capsule, 
                             routings=routing_count, 
                             name='digitcaps')(primary_capsule)    
   
   out_caps = Length(name='capsnet')(digitcaps)
   train_model = models.Model(input,outputs=out_caps)
   
   return train_model

# %%
def margin_loss(y_true, y_pred):
    
    L = y_true * tf.square(tf.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * tf.square(tf.maximum(0., y_pred - 0.1))
    return tf.reduce_mean(tf.reduce_sum(L, 1))

# %% [markdown]
# # Train

# %%
# Train Capsule Network
@tf.autograph.experimental.do_not_convert
def train(model, data, args):
    """
    Training a CapsuleNet
    @param model: the CapsuleNet model
    @param data: a tuple containing training and testing data, like `((x_train, y_train), (x_test, y_test))`
    @param args: arguments
    return: The trained model
    """
    # unpacking the data
    (x_train, y_train), (x_test, y_test) = data

    # callbacks to save the best model   
    checkpoint = callbacks.ModelCheckpoint(args.save_dir + '/weights.h5', monitor='val_accuracy',
                                           save_best_only=True, save_weights_only=True, verbose=1)    
    # compile the model
    model.compile(optimizer=optimizers.Adam(lr=args.lr),
                  loss=[margin_loss, 'mse'],
                  loss_weights=[1., args.lam_recon],run_eagerly=True,
                  metrics={'capsnet': 'accuracy'})

    # Train the model
    train_image_generator = ImageDataGenerator()  
    train_data_generator = train_image_generator.flow(x_train, y_train, batch_size=args.batch_size)
    val_image_generator = ImageDataGenerator()
    val_data_generator = val_image_generator.flow(x_test,y_test,batch_size = args.batch_size)
   
    history = model.fit(train_data_generator,
              steps_per_epoch=int(y_train.shape[0] / args.batch_size),
              epochs=args.epochs,              
              validation_data=val_data_generator, batch_size=args.batch_size,
              callbacks=[checkpoint])
 
    index = history.history["val_accuracy"].index(max(history.history["val_accuracy"]))
    best_val_accuracy = history.history["val_accuracy"][index]    
    print(f"Best Validation Accuracy:{best_val_accuracy}") 
    plot_model_performance(history)
   
    return model

# %% [markdown]
# # Plot Model Performance

# %%
from matplotlib import pyplot as plt
def plot_model_performance(history):
  plt.style.use("ggplot")
  plt.figure(figsize=(7,6))
  epoch_ran = len(history.history["loss"])
  plt.plot(np.arange(0, epoch_ran), \
           history.history["loss"], label="train_loss")
  plt.plot(np.arange(0, epoch_ran), \
           history.history["val_loss"], label="val_loss")
  plt.plot(np.arange(0, epoch_ran), \
           history.history["accuracy"], label="train_acc")
  plt.plot(np.arange(0, epoch_ran), \
           history.history["val_accuracy"], label="val_acc")
  plt.title("Training Loss and Accuracy")
  plt.xlabel("Epoch #")
  plt.ylabel("Loss/Accuracy")
  plt.legend()
  plt.show()

# %% [markdown]
# # Train and Test The Model

# %%
@tf.autograph.experimental.do_not_convert
def get_model_train_test(data,args,n_channels = 32,
                                      dim_capsule=16,
                                      kernels=[9],
                                      filters=[256],
                                      strides=[1],
                                      multi_level_feature_extraction = False):
  set_seed()
  (x_train,y_train),(x_test,y_test) = data
  # Build the model
  model = CapsuleNet.build(input_shape=x_train.shape[1:], 
                                      number_of_class=len(np.unique(np.argmax(y_train, 1))),
                                      routing_count=args.routings,
                                      batch_size=args.batch_size,
                                      n_channels=n_channels,
                                      dim_capsule = dim_capsule,
                                      kernels = kernels,
                                      filters= filters,
                                      strides = strides,
                                      primary_caps_dim = 8,
                                      multi_level_feature_extraction=multi_level_feature_extraction)

  model.summary()
  # Train the model
  trained_model = train(model=model, data=((x_train, y_train), (x_test, y_test)), args=args)
  #Load the weight where accuracy was maximum
  trained_model.load_weights(f'./result/weights.h5')
  # Model Training Done
  #Prediction and calculate the matrix value
 
  y_pred= trained_model.predict(x_test,batch_size=x_test.shape[0])
  
  print("*******Model Performance*************")
  print('Test acc:', np.sum(np.argmax(y_pred, 1) == np.argmax(y_test, 1)) / y_test.shape[0])  

 
  result_pred = np.argmax(y_pred, axis=1) 
  result_actual = np.argmax(y_test, axis=1) 
  precision = precision_score(result_actual, result_pred)
  recall = recall_score(result_actual, result_pred)
  f1 = f1_score(result_actual, result_pred)
  tn, fp, fn, tp = confusion_matrix(result_actual, result_pred).ravel()
  fpr, tpr, thresholds = metrics.roc_curve(result_actual, result_pred)
  auc = metrics.auc(fpr, tpr)
  
  print(f"Precision:{precision}")
  print(f"recall:{recall}")
  print(f"f1:{f1}")
  print(f"AUC:{auc}")
  print(f"Sensitivity:{tp/(tp+fn)}")
  print(f"specificity:{tn/(tn+fp)}")

# %% [markdown]
# # Arguments

# %%
import argparse
import os
def get_arguments():
    parser = argparse.ArgumentParser(description="Capsule Network Glaucoma Classification.")
    parser.add_argument('--epochs', default=15, type=int)
    parser.add_argument('--batch_size', default=32, type=int)
    parser.add_argument('--lr', default=0.0001, type=float,
                            help="Initial learning rate")
    parser.add_argument('--lr_decay', default=1, type=float,
                        help="The value multiplied by lr at each epoch. Set a larger value for larger epochs")
    parser.add_argument('--lam_recon', default=0.392, type=float,
                        help="The coefficient for the loss of decoder")
    parser.add_argument('-r', '--routings', default=1, type=int,
                        help="Number of iterations used in routing algorithm. should > 0")
    parser.add_argument('--shift_fraction', default=0.1, type=float,
                        help="Fraction of pixels to shift at most in each direction.")
    parser.add_argument('--debug', action='store_true',
                        help="Save weights by TensorBoard")
    parser.add_argument('--save_dir', default='./result')
    parser.add_argument('--augmentation', default=False, type=bool)
    parser.add_argument('-t', '--testing', action='store_true',
                        help="Test the trained model on testing dataset")
    parser.add_argument('--digit', default=5, type=int,
                        help="Digit to manipulate")
    parser.add_argument('-w', '--weights', default=None,
                        help="The path of the saved weights. Should be specified when testing")
    args, unknown = parser.parse_known_args()
    print(args)

    if not os.path.exists(args.save_dir):
        os.makedirs(args.save_dir)
    
    return args

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Load DataSet

# %%
#RIM_ONE_DL_DIR = '/content/gdrive/My Drive/dataset/rim_one_dl/partitioned_randomly'
RIM_ONE_DL_DIR = 'C:\gyani\Projects_MS\code\dataset\RIM-ONE_DL_images\partitioned_randomly'
ACRIMA_DIR = 'C:\gyani\Projects_MS\code\dataset\ACRIMA_dataset\Database'
RIM_ONE_R2_DIR = 'C:\gyani\Projects_MS\code\dataset\RIMONE-db-r2'

# %% [markdown]
# Image Size

# %%
HEIGHT= 32
WIDTH = 32

# %% [markdown]
# Preprocess Image: Generate Array

# %%
# Resize image to HEIGHT*WIDTH
# Convert to numpy array
def process_image(data_set_dir, label_dict, width,height,histogram_eq = False):
    
    x = [] # will store images as arrays
    y = [] # store labels
    # list folders in directory
    directories = os.listdir(data_set_dir)
     
    # for each folder (train and validation) 
    for label in directories:
        
        # add class label to label dictionary
        if label not in label_dict:
            label_dict[label] = len(label_dict)
        
        # create full path for image directory 
        source_images = os.path.join(data_set_dir, label)
        images = os.listdir(source_images)
        # for each image in directory, 
        for image in images:
            #folder have .txt files which needs to be ignored
            if '.txt'not in image:
                # read the image from file, resize and add to a list
                full_size_image = cv2.imread(os.path.join(source_images, image))
                #gray_image = cv2.cvtColor(full_size_image, cv2.COLOR_BGR2GRAY)
                if histogram_eq == True:
                  full_size_image_YUW = cv2.cvtColor(full_size_image, cv2.COLOR_BGR2YUV)
                  full_size_image_YUW[:,:,0] = cv2.equalizeHist(full_size_image_YUW[:,:,0])
                  full_size_image = cv2.cvtColor(full_size_image_YUW, cv2.COLOR_YUV2BGR)
                #append the image to x
                x.append(cv2.resize(full_size_image, (width,height), 
                                                            interpolation=cv2.INTER_CUBIC))
                # add the class label to y
                y.append(label)

    data = np.array(x, dtype="float") / 255.0                
    label = np.array(y)
    
    return data,label

# %% [markdown]
# # RIMONE DL

# %%
def get_rim_one_dl(histogram_eq = False):
  class_labels = {}
  training_images,training_labels = process_image(RIM_ONE_DL_DIR+"/training_set",
                                                  class_labels,
                                                  WIDTH,HEIGHT,
                                                  histogram_eq = histogram_eq)
  
  training_label = (pd.Series(training_labels).map(class_labels)).values
  training_label = to_categorical(training_label.astype('float32'))
  training_images = training_images.reshape(-1, WIDTH, WIDTH, 3).astype('float32')

  test_images,test_labels = process_image(RIM_ONE_DL_DIR+"/test_set",
                                          class_labels,
                                          WIDTH,HEIGHT,
                                          histogram_eq = histogram_eq)
  
  test_label = (pd.Series(test_labels).map(class_labels)).values
  test_label = to_categorical(test_label.astype('float32'))
  test_images = test_images.reshape(-1, WIDTH, WIDTH, 3).astype('float32')

  return (training_images,training_label),(test_images,test_label)

# %% [markdown]
# # RIMEONE V2

# %%
def get_rim_one_db_r2(test_train_ratio = 0.2,histogram_eq = False):
  
  class_labels = {}
  training_images,training_labels = process_image(RIM_ONE_R2_DIR,
                                                  class_labels,
                                                  WIDTH,HEIGHT,
                                                  histogram_eq = histogram_eq)
  
  training_label = (pd.Series(training_labels).map(class_labels)).values
  training_label = to_categorical(training_label.astype('float32'))
  training_images = training_images.reshape(-1, WIDTH, WIDTH, 3).astype('float32')

  X_train, X_test, y_train, y_test = train_test_split(training_images, 
                                                      training_label, 
                                                      test_size=test_train_ratio, 
                                                      random_state=100)

  return (X_train,y_train),(X_test,y_test)

# %% [markdown]
# # ACRIMA

# %%
def get_acrima_dataset(test_train_ratio = 0.2,histogram_eq = False):
  class_labels = {}
  training_images,training_labels = process_image(ACRIMA_DIR,
                                                  class_labels,
                                                  WIDTH,HEIGHT,
                                                  histogram_eq = histogram_eq)
  
  training_label = (pd.Series(training_labels).map(class_labels)).values
  training_label = to_categorical(training_label.astype('float32'))
  training_images = training_images.reshape(-1, WIDTH, WIDTH, 3).astype('float32')

  X_train, X_test, y_train, y_test = train_test_split(training_images, 
                                                      training_label, 
                                                      test_size=test_train_ratio, 
                                                      random_state=100)

  return (X_train,y_train),(X_test,y_test)

# %% [markdown]
# # RIMONE DL

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 50
args.routings = 1
data = get_rim_one_dl()
get_model_train_test(data,args)
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(32, 32, 32, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 24, 24, 256)         62464
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 16, 16, 256)         5308672
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 8192, 8)             0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 8192, 8)             0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               2097152
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 7,468,288
# Trainable params: 7,468,288
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 6s 222ms/step - loss: 0.4253 - accuracy: 0.6352 - val_loss: 0.2764 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/50
# 10/10 [==============================] - 1s 136ms/step - loss: 0.2588 - accuracy: 0.6482 - val_loss: 0.2720 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/50
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2549 - accuracy: 0.6515 - val_loss: 0.2615 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/50
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2437 - accuracy: 0.6482 - val_loss: 0.2618 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/50
# 10/10 [==============================] - 1s 136ms/step - loss: 0.2347 - accuracy: 0.6482 - val_loss: 0.2385 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/50
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2057 - accuracy: 0.6808 - val_loss: 0.2091 - val_accuracy: 0.6507
#
# Epoch 00006: val_accuracy improved from 0.64384 to 0.65068, saving model to ./result\weights.h5
# Epoch 7/50
# 10/10 [==============================] - 1s 136ms/step - loss: 0.1901 - accuracy: 0.6808 - val_loss: 0.2294 - val_accuracy: 0.5959
#
# Epoch 00007: val_accuracy did not improve from 0.65068
# Epoch 8/50
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2079 - accuracy: 0.6384 - val_loss: 0.2306 - val_accuracy: 0.6438
#
# Epoch 00008: val_accuracy did not improve from 0.65068
# Epoch 9/50
# 10/10 [==============================] - 1s 141ms/step - loss: 0.2043 - accuracy: 0.6645 - val_loss: 0.1917 - val_accuracy: 0.6712
#
# Epoch 00009: val_accuracy improved from 0.65068 to 0.67123, saving model to ./result\weights.h5
# Epoch 10/50
# 10/10 [==============================] - 1s 141ms/step - loss: 0.1723 - accuracy: 0.6906 - val_loss: 0.1790 - val_accuracy: 0.6575
#
# Epoch 00010: val_accuracy did not improve from 0.67123
# Epoch 11/50
# 10/10 [==============================] - 1s 139ms/step - loss: 0.1641 - accuracy: 0.7003 - val_loss: 0.1527 - val_accuracy: 0.7123
#
# Epoch 00011: val_accuracy improved from 0.67123 to 0.71233, saving model to ./result\weights.h5
# Epoch 12/50
# 10/10 [==============================] - 1s 141ms/step - loss: 0.1569 - accuracy: 0.7296 - val_loss: 0.1547 - val_accuracy: 0.7192
#
# Epoch 00012: val_accuracy improved from 0.71233 to 0.71918, saving model to ./result\weights.h5
# Epoch 13/50
# 10/10 [==============================] - 1s 138ms/step - loss: 0.1366 - accuracy: 0.7655 - val_loss: 0.1329 - val_accuracy: 0.7534
#
# Epoch 00013: val_accuracy improved from 0.71918 to 0.75342, saving model to ./result\weights.h5
# Epoch 14/50
# 10/10 [==============================] - 1s 140ms/step - loss: 0.1447 - accuracy: 0.7655 - val_loss: 0.1413 - val_accuracy: 0.7808
#
# Epoch 00014: val_accuracy improved from 0.75342 to 0.78082, saving model to ./result\weights.h5
# Epoch 15/50
# 10/10 [==============================] - 1s 136ms/step - loss: 0.1509 - accuracy: 0.7524 - val_loss: 0.1347 - val_accuracy: 0.7603
#
# Epoch 00015: val_accuracy did not improve from 0.78082
# Epoch 16/50
# 10/10 [==============================] - 1s 137ms/step - loss: 0.1449 - accuracy: 0.7394 - val_loss: 0.1193 - val_accuracy: 0.7945
#
# Epoch 00016: val_accuracy improved from 0.78082 to 0.79452, saving model to ./result\weights.h5
# Epoch 17/50
# 10/10 [==============================] - 1s 142ms/step - loss: 0.1118 - accuracy: 0.8339 - val_loss: 0.1029 - val_accuracy: 0.8630
#
# Epoch 00017: val_accuracy improved from 0.79452 to 0.86301, saving model to ./result\weights.h5
# Epoch 18/50
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0996 - accuracy: 0.8469 - val_loss: 0.1016 - val_accuracy: 0.8425
#
# Epoch 00018: val_accuracy did not improve from 0.86301
# Epoch 19/50
# 10/10 [==============================] - 1s 148ms/step - loss: 0.0976 - accuracy: 0.8534 - val_loss: 0.1063 - val_accuracy: 0.8356
#
# Epoch 00019: val_accuracy did not improve from 0.86301
# Epoch 20/50
# 10/10 [==============================] - 1s 150ms/step - loss: 0.1020 - accuracy: 0.8599 - val_loss: 0.0988 - val_accuracy: 0.8767
#
# Epoch 00020: val_accuracy improved from 0.86301 to 0.87671, saving model to ./result\weights.h5
# Epoch 21/50
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0983 - accuracy: 0.8404 - val_loss: 0.0971 - val_accuracy: 0.8836
#
# Epoch 00021: val_accuracy improved from 0.87671 to 0.88356, saving model to ./result\weights.h5
# Epoch 22/50
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0909 - accuracy: 0.8656 - val_loss: 0.0940 - val_accuracy: 0.8767
#
# Epoch 00022: val_accuracy did not improve from 0.88356
# Epoch 23/50
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0922 - accuracy: 0.8534 - val_loss: 0.0925 - val_accuracy: 0.8767
#
# Epoch 00023: val_accuracy did not improve from 0.88356
# Epoch 24/50
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0875 - accuracy: 0.8664 - val_loss: 0.0907 - val_accuracy: 0.8904
#
# Epoch 00024: val_accuracy improved from 0.88356 to 0.89041, saving model to ./result\weights.h5
# Epoch 25/50
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0858 - accuracy: 0.8697 - val_loss: 0.1013 - val_accuracy: 0.8699
#
# Epoch 00025: val_accuracy did not improve from 0.89041
# Epoch 26/50
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0859 - accuracy: 0.8730 - val_loss: 0.0941 - val_accuracy: 0.8836
#
# Epoch 00026: val_accuracy did not improve from 0.89041
# Epoch 27/50
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0822 - accuracy: 0.8762 - val_loss: 0.0990 - val_accuracy: 0.8630
#
# Epoch 00027: val_accuracy did not improve from 0.89041
# Epoch 28/50
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0873 - accuracy: 0.8781 - val_loss: 0.0871 - val_accuracy: 0.8836
#
# Epoch 00028: val_accuracy did not improve from 0.89041
# Epoch 29/50
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0812 - accuracy: 0.8795 - val_loss: 0.0957 - val_accuracy: 0.8630
#
# Epoch 00029: val_accuracy did not improve from 0.89041
# Epoch 30/50
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0845 - accuracy: 0.8860 - val_loss: 0.0887 - val_accuracy: 0.8767
#
# Epoch 00030: val_accuracy did not improve from 0.89041
# Epoch 31/50
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0814 - accuracy: 0.8697 - val_loss: 0.0924 - val_accuracy: 0.8767
#
# Epoch 00031: val_accuracy did not improve from 0.89041
# Epoch 32/50
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0815 - accuracy: 0.8762 - val_loss: 0.0921 - val_accuracy: 0.8836
#
# Epoch 00032: val_accuracy did not improve from 0.89041
# Epoch 33/50
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0803 - accuracy: 0.8730 - val_loss: 0.0912 - val_accuracy: 0.8973
#
# Epoch 00033: val_accuracy improved from 0.89041 to 0.89726, saving model to ./result\weights.h5
# Epoch 34/50
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0745 - accuracy: 0.8958 - val_loss: 0.0926 - val_accuracy: 0.8699
#
# Epoch 00034: val_accuracy did not improve from 0.89726
# Epoch 35/50
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0727 - accuracy: 0.8860 - val_loss: 0.0943 - val_accuracy: 0.8699
#
# Epoch 00035: val_accuracy did not improve from 0.89726
# Epoch 36/50
# 10/10 [==============================] - 2s 165ms/step - loss: 0.0699 - accuracy: 0.9023 - val_loss: 0.0869 - val_accuracy: 0.8836
#
# Epoch 00036: val_accuracy did not improve from 0.89726
# Epoch 37/50
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0746 - accuracy: 0.8860 - val_loss: 0.0876 - val_accuracy: 0.8973
#
# Epoch 00037: val_accuracy did not improve from 0.89726
# Epoch 38/50
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0706 - accuracy: 0.8925 - val_loss: 0.0906 - val_accuracy: 0.8767
#
# Epoch 00038: val_accuracy did not improve from 0.89726
# Epoch 39/50
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0654 - accuracy: 0.8958 - val_loss: 0.0894 - val_accuracy: 0.8767
#
# Epoch 00039: val_accuracy did not improve from 0.89726
# Epoch 40/50
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0694 - accuracy: 0.8925 - val_loss: 0.0881 - val_accuracy: 0.8699
#
# Epoch 00040: val_accuracy did not improve from 0.89726
# Epoch 41/50
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0677 - accuracy: 0.8958 - val_loss: 0.0893 - val_accuracy: 0.8767
#
# Epoch 00041: val_accuracy did not improve from 0.89726
# Epoch 42/50
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0687 - accuracy: 0.8958 - val_loss: 0.0834 - val_accuracy: 0.8767
#
# Epoch 00042: val_accuracy did not improve from 0.89726
# Epoch 43/50
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0645 - accuracy: 0.9023 - val_loss: 0.0924 - val_accuracy: 0.8562
#
# Epoch 00043: val_accuracy did not improve from 0.89726
# Epoch 44/50
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0635 - accuracy: 0.9088 - val_loss: 0.0835 - val_accuracy: 0.8904
#
# Epoch 00044: val_accuracy did not improve from 0.89726
# Epoch 45/50
# 10/10 [==============================] - 2s 152ms/step - loss: 0.0626 - accuracy: 0.8958 - val_loss: 0.0917 - val_accuracy: 0.8630
#
# Epoch 00045: val_accuracy did not improve from 0.89726
# Epoch 46/50
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0604 - accuracy: 0.9186 - val_loss: 0.0832 - val_accuracy: 0.8699
#
# Epoch 00046: val_accuracy did not improve from 0.89726
# Epoch 47/50
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0604 - accuracy: 0.9251 - val_loss: 0.0852 - val_accuracy: 0.8973
#
# Epoch 00047: val_accuracy did not improve from 0.89726
# Epoch 48/50
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0610 - accuracy: 0.9218 - val_loss: 0.0858 - val_accuracy: 0.8767
#
# Epoch 00048: val_accuracy did not improve from 0.89726
# Epoch 49/50
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0593 - accuracy: 0.9088 - val_loss: 0.0835 - val_accuracy: 0.8699
#
# Epoch 00049: val_accuracy did not improve from 0.89726
# Epoch 50/50
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0579 - accuracy: 0.9218 - val_loss: 0.0946 - val_accuracy: 0.8356
#
# Epoch 00050: val_accuracy did not improve from 0.89726
# Best Validation Accuracy:0.8972602486610413
# *******Model Performance*************
# Test acc: 0.8972602739726028
# Precision:0.898989898989899
# recall:0.9468085106382979
# f1:0.9222797927461138
# AUC:0.8772504091653027
# Sensitivity:0.9468085106382979
# specificity:0.8076923076923077
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 36' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000035?line=4'>5</a> data = get_rim_one_dl()
#       <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000035?line=5'>6</a> get_model_train_test(data,args)
# ----> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000035?line=6'>7</a> get_model_train_test(data,args,kernels= [5,7,9],filters=[8,16,32],strides=[1,2,1])
#       <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000035?line=7'>8</a> get_model_train_test(data,args,kernels= [5,7,9],filters=[8,16,32],strides=[1,2,1])
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\autograph\impl\api.py:649, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=646'>647</a> def wrapper(*args, **kwargs):
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=647'>648</a>   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=648'>649</a>     return func(*args, **kwargs)
#
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 19' in get_model_train_test(data, args, n_channels, dim_capsule, kernels, filters, strides, multi_level_feature_extraction)
#       <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=8'>9</a> (x_train,y_train),(x_test,y_test) = data
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=9'>10</a> # Build the model
# ---> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=10'>11</a> model = CapsuleNet.build(input_shape=x_train.shape[1:],
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=11'>12</a>                                     number_of_class=len(np.unique(np.argmax(y_train, 1))),
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=12'>13</a>                                     routing_count=args.routings,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=13'>14</a>                                     batch_size=args.batch_size,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=14'>15</a>                                     n_channels=n_channels,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=15'>16</a>                                     dim_capsule = dim_capsule,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=16'>17</a>                                     kernels = kernels,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=17'>18</a>                                     filters= filters,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=18'>19</a>                                     strides = strides,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=19'>20</a>                                     primary_caps_dim = 8,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=20'>21</a>                                     multi_level_feature_extraction=multi_level_feature_extraction)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=22'>23</a> model.summary()
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=23'>24</a> # Train the model
#
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 12' in CapsuleNet.build(input_shape, number_of_class, routing_count, batch_size, n_channels, dim_capsule, primary_caps_dim, kernels, filters, strides, multi_level_feature_extraction)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=50'>51</a>          conv = layers.Conv2D(filters=filters[index],
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=51'>52</a>                              kernel_size=kernels[index],
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=52'>53</a>                              strides=strides[index],
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=53'>54</a>                              padding='valid',
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=54'>55</a>                              activation='relu',
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=55'>56</a>                              name='conv'+str(index))(conv)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=56'>57</a> n_channels = filters[-1]//primary_caps_dim
# ---> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=57'>58</a> primary_capsule = PrimaryCap(conv, primary_caps_dim, n_channels, kernels[-1], strides[-1], 'valid')
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=59'>60</a> digitcaps = CapsuleLayer(num_capsule=number_of_class,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=60'>61</a>                           dim_capsule=dim_capsule,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=61'>62</a>                           routings=routing_count,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=62'>63</a>                           name='digitcaps')(primary_capsule)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000011?line=64'>65</a> out_caps = Length(name='capsnet')(digitcaps)
#
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 10' in PrimaryCap(inputs, dim_capsule, n_channels, kernel_size, strides, padding)
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=121'>122</a> def PrimaryCap(inputs, dim_capsule, n_channels, kernel_size, strides, padding):
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=122'>123</a>     """
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=123'>124</a>     Apply Conv2D `n_channels` times and concatenate all capsules
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=124'>125</a>     @param inputs: 4D tensor, shape=[None, width, height, channels]
#    (...)
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=127'>128</a>     @return: output tensor, shape=[None, num_capsule, dim_capsule]
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=128'>129</a>     """
# --> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=129'>130</a>     output = layers.Conv2D(filters = dim_capsule*n_channels,
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=130'>131</a>                            kernel_size = kernel_size,
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=131'>132</a>                            strides = strides,
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=132'>133</a>                            padding = padding,
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=133'>134</a>                            name='primarycap_conv2d')(inputs)
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=134'>135</a>     outputs = layers.Reshape(target_shape = [-1, dim_capsule],
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=135'>136</a>                              name = 'primarycap_reshape')(output)
#     <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=137'>138</a>     return layers.Lambda(squash, name='primarycap_squash')(outputs)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:983, in Layer.__call__(self, *args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=976'>977</a> # Functional Model construction mode is invoked when `Layer`s are called on
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=977'>978</a> # symbolic `KerasTensor`s, i.e.:
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=978'>979</a> # >> inputs = tf.keras.Input(10)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=979'>980</a> # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=980'>981</a> # >> model = tf.keras.Model(inputs, outputs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=981'>982</a> if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=982'>983</a>   return self._functional_construction_call(inputs, args, kwargs,
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=983'>984</a>                                             input_list)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=985'>986</a> # Maintains info about the `Layer.call` stack.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=986'>987</a> call_context = base_layer_utils.call_context()
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1121, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1115'>1116</a>     training_arg_passed_by_framework = True
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1117'>1118</a> with call_context.enter(
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1118'>1119</a>     layer=self, inputs=inputs, build_graph=True, training=training_value):
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1119'>1120</a>   # Check input assumptions set after layer building, e.g. input shape.
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1120'>1121</a>   outputs = self._keras_tensor_symbolic_call(
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1121'>1122</a>       inputs, input_masks, args, kwargs)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1123'>1124</a>   if outputs is None:
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1124'>1125</a>     raise ValueError('A layer\'s `call` method should return a '
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1125'>1126</a>                      'Tensor or a list of Tensors, not None '
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1126'>1127</a>                      '(layer: ' + self.name + ').')
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:854, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=851'>852</a>   return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=852'>853</a> else:
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=853'>854</a>   return self._infer_output_signature(inputs, args, kwargs, input_masks)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:894, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=891'>892</a>     self._maybe_build(inputs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=892'>893</a>     inputs = self._maybe_cast_inputs(inputs)
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=893'>894</a>     outputs = call_fn(inputs, *args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=895'>896</a>   self._handle_activity_regularization(inputs, outputs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=896'>897</a> self._set_mask_metadata(inputs, outputs, input_masks,
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=897'>898</a>                         build_graph=False)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\layers\convolutional.py:253, in Conv.call(self, inputs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/layers/convolutional.py?line=249'>250</a> if self._is_causal:  # Apply causal padding to inputs for Conv1D.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/layers/convolutional.py?line=250'>251</a>   inputs = array_ops.pad(inputs, self._compute_causal_padding(inputs))
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/layers/convolutional.py?line=252'>253</a> outputs = self._convolution_op(inputs, self.kernel)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/layers/convolutional.py?line=254'>255</a> if self.use_bias:
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/layers/convolutional.py?line=255'>256</a>   output_rank = outputs.shape.rank
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=152'>153</a>   raise e.with_traceback(filtered_tb) from None
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=153'>154</a> finally:
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=154'>155</a>   del filtered_tb
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\framework\ops.py:1939, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/framework/ops.py?line=1935'>1936</a>   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/framework/ops.py?line=1936'>1937</a> except errors.InvalidArgumentError as e:
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/framework/ops.py?line=1937'>1938</a>   # Convert to ValueError for backwards compatibility.
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/framework/ops.py?line=1938'>1939</a>   raise ValueError(e.message)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/framework/ops.py?line=1940'>1941</a> return c_op
#
# ValueError: Negative dimension size caused by subtracting 9 from 3 for '{{node primarycap_conv2d/Conv2D}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](Placeholder, primarycap_conv2d/Conv2D/ReadVariableOp)' with input shapes: [32,3,3,32], [9,9,32,32].

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=64
WIDTH=64
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [7,9],filters=[32,64],strides=[1,2])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(32, 64, 64, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 58, 58, 32)          4736
# _________________________________________________________________
# conv1 (Conv2D)               (32, 25, 25, 64)          165952
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 9, 9, 64)            331840
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 648, 8)              0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 648, 8)              0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               165888
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 668,416
# Trainable params: 668,416
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 3s 223ms/step - loss: 0.4800 - accuracy: 0.6352 - val_loss: 0.2706 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2508 - accuracy: 0.6482 - val_loss: 0.2557 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2339 - accuracy: 0.6515 - val_loss: 0.2346 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2167 - accuracy: 0.6482 - val_loss: 0.2098 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2010 - accuracy: 0.6482 - val_loss: 0.2039 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.1990 - accuracy: 0.6482 - val_loss: 0.2015 - val_accuracy: 0.6438
#
# Epoch 00006: val_accuracy did not improve from 0.64384
# Epoch 7/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.1971 - accuracy: 0.6482 - val_loss: 0.1989 - val_accuracy: 0.6438
#
# Epoch 00007: val_accuracy did not improve from 0.64384
# Epoch 8/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.1951 - accuracy: 0.6482 - val_loss: 0.2005 - val_accuracy: 0.6438
#
# Epoch 00008: val_accuracy did not improve from 0.64384
# Epoch 9/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.1991 - accuracy: 0.6417 - val_loss: 0.1962 - val_accuracy: 0.6438
#
# Epoch 00009: val_accuracy did not improve from 0.64384
# Epoch 10/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.1925 - accuracy: 0.6531 - val_loss: 0.1938 - val_accuracy: 0.6438
#
# Epoch 00010: val_accuracy did not improve from 0.64384
# Epoch 11/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.1917 - accuracy: 0.6547 - val_loss: 0.1994 - val_accuracy: 0.6507
#
# Epoch 00011: val_accuracy improved from 0.64384 to 0.65068, saving model to ./result\weights.h5
# Epoch 12/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.1795 - accuracy: 0.6645 - val_loss: 0.1930 - val_accuracy: 0.6370
#
# Epoch 00012: val_accuracy did not improve from 0.65068
# Epoch 13/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.1757 - accuracy: 0.6906 - val_loss: 0.1864 - val_accuracy: 0.6644
#
# Epoch 00013: val_accuracy improved from 0.65068 to 0.66438, saving model to ./result\weights.h5
# Epoch 14/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.1718 - accuracy: 0.6808 - val_loss: 0.1775 - val_accuracy: 0.6507
#
# Epoch 00014: val_accuracy did not improve from 0.66438
# Epoch 15/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.1667 - accuracy: 0.7101 - val_loss: 0.1754 - val_accuracy: 0.6849
#
# Epoch 00015: val_accuracy improved from 0.66438 to 0.68493, saving model to ./result\weights.h5
# Epoch 16/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.1665 - accuracy: 0.6775 - val_loss: 0.1686 - val_accuracy: 0.6781
#
# Epoch 00016: val_accuracy did not improve from 0.68493
# Epoch 17/100
# 10/10 [==============================] - 1s 147ms/step - loss: 0.1480 - accuracy: 0.7524 - val_loss: 0.1560 - val_accuracy: 0.7260
#
# Epoch 00017: val_accuracy improved from 0.68493 to 0.72603, saving model to ./result\weights.h5
# Epoch 18/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.1437 - accuracy: 0.7427 - val_loss: 0.1511 - val_accuracy: 0.7466
#
# Epoch 00018: val_accuracy improved from 0.72603 to 0.74658, saving model to ./result\weights.h5
# Epoch 19/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.1345 - accuracy: 0.7622 - val_loss: 0.1366 - val_accuracy: 0.7534
#
# Epoch 00019: val_accuracy improved from 0.74658 to 0.75342, saving model to ./result\weights.h5
# Epoch 20/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.1307 - accuracy: 0.7524 - val_loss: 0.1330 - val_accuracy: 0.7808
#
# Epoch 00020: val_accuracy improved from 0.75342 to 0.78082, saving model to ./result\weights.h5
# Epoch 21/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.1247 - accuracy: 0.7818 - val_loss: 0.1236 - val_accuracy: 0.8082
#
# Epoch 00021: val_accuracy improved from 0.78082 to 0.80822, saving model to ./result\weights.h5
# Epoch 22/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.1130 - accuracy: 0.8156 - val_loss: 0.1185 - val_accuracy: 0.8219
#
# Epoch 00022: val_accuracy improved from 0.80822 to 0.82192, saving model to ./result\weights.h5
# Epoch 23/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.1136 - accuracy: 0.8111 - val_loss: 0.1118 - val_accuracy: 0.8493
#
# Epoch 00023: val_accuracy improved from 0.82192 to 0.84932, saving model to ./result\weights.h5
# Epoch 24/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.1090 - accuracy: 0.8078 - val_loss: 0.1114 - val_accuracy: 0.8356
#
# Epoch 00024: val_accuracy did not improve from 0.84932
# Epoch 25/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.1052 - accuracy: 0.8469 - val_loss: 0.1043 - val_accuracy: 0.8493
#
# Epoch 00025: val_accuracy did not improve from 0.84932
# Epoch 26/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0974 - accuracy: 0.8274 - val_loss: 0.1041 - val_accuracy: 0.8562
#
# Epoch 00026: val_accuracy improved from 0.84932 to 0.85616, saving model to ./result\weights.h5
# Epoch 27/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0922 - accuracy: 0.8534 - val_loss: 0.1028 - val_accuracy: 0.8630
#
# Epoch 00027: val_accuracy improved from 0.85616 to 0.86301, saving model to ./result\weights.h5
# Epoch 28/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0946 - accuracy: 0.8375 - val_loss: 0.1012 - val_accuracy: 0.8699
#
# Epoch 00028: val_accuracy improved from 0.86301 to 0.86986, saving model to ./result\weights.h5
# Epoch 29/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0934 - accuracy: 0.8436 - val_loss: 0.1035 - val_accuracy: 0.8699
#
# Epoch 00029: val_accuracy did not improve from 0.86986
# Epoch 30/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0951 - accuracy: 0.8632 - val_loss: 0.1042 - val_accuracy: 0.8493
#
# Epoch 00030: val_accuracy did not improve from 0.86986
# Epoch 31/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0892 - accuracy: 0.8599 - val_loss: 0.1039 - val_accuracy: 0.8562
#
# Epoch 00031: val_accuracy did not improve from 0.86986
# Epoch 32/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0916 - accuracy: 0.8599 - val_loss: 0.0961 - val_accuracy: 0.8630
#
# Epoch 00032: val_accuracy did not improve from 0.86986
# Epoch 33/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0861 - accuracy: 0.8502 - val_loss: 0.1030 - val_accuracy: 0.8493
#
# Epoch 00033: val_accuracy did not improve from 0.86986
# Epoch 34/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0818 - accuracy: 0.8730 - val_loss: 0.0945 - val_accuracy: 0.8562
#
# Epoch 00034: val_accuracy did not improve from 0.86986
# Epoch 35/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0819 - accuracy: 0.8860 - val_loss: 0.0997 - val_accuracy: 0.8630
#
# Epoch 00035: val_accuracy did not improve from 0.86986
# Epoch 36/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0791 - accuracy: 0.8730 - val_loss: 0.0972 - val_accuracy: 0.8630
#
# Epoch 00036: val_accuracy did not improve from 0.86986
# Epoch 37/100
# 10/10 [==============================] - 1s 147ms/step - loss: 0.0858 - accuracy: 0.8469 - val_loss: 0.0937 - val_accuracy: 0.8630
#
# Epoch 00037: val_accuracy did not improve from 0.86986
# Epoch 38/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0799 - accuracy: 0.8795 - val_loss: 0.0942 - val_accuracy: 0.8630
#
# Epoch 00038: val_accuracy did not improve from 0.86986
# Epoch 39/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0742 - accuracy: 0.8860 - val_loss: 0.0960 - val_accuracy: 0.8699
#
# Epoch 00039: val_accuracy did not improve from 0.86986
# Epoch 40/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0794 - accuracy: 0.8730 - val_loss: 0.0927 - val_accuracy: 0.8630
#
# Epoch 00040: val_accuracy did not improve from 0.86986
# Epoch 41/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0794 - accuracy: 0.8762 - val_loss: 0.0940 - val_accuracy: 0.8699
#
# Epoch 00041: val_accuracy did not improve from 0.86986
# Epoch 42/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0775 - accuracy: 0.8697 - val_loss: 0.0901 - val_accuracy: 0.8836
#
# Epoch 00042: val_accuracy improved from 0.86986 to 0.88356, saving model to ./result\weights.h5
# Epoch 43/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0714 - accuracy: 0.9023 - val_loss: 0.0972 - val_accuracy: 0.8493
#
# Epoch 00043: val_accuracy did not improve from 0.88356
# Epoch 44/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0764 - accuracy: 0.8860 - val_loss: 0.0933 - val_accuracy: 0.8767
#
# Epoch 00044: val_accuracy did not improve from 0.88356
# Epoch 45/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0752 - accuracy: 0.8827 - val_loss: 0.1017 - val_accuracy: 0.8425
#
# Epoch 00045: val_accuracy did not improve from 0.88356
# Epoch 46/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0754 - accuracy: 0.8762 - val_loss: 0.0917 - val_accuracy: 0.8767
#
# Epoch 00046: val_accuracy did not improve from 0.88356
# Epoch 47/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0754 - accuracy: 0.8893 - val_loss: 0.0948 - val_accuracy: 0.8562
#
# Epoch 00047: val_accuracy did not improve from 0.88356
# Epoch 48/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0789 - accuracy: 0.8730 - val_loss: 0.0939 - val_accuracy: 0.8767
#
# Epoch 00048: val_accuracy did not improve from 0.88356
# Epoch 49/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0724 - accuracy: 0.8860 - val_loss: 0.0925 - val_accuracy: 0.8699
#
# Epoch 00049: val_accuracy did not improve from 0.88356
# Epoch 50/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0753 - accuracy: 0.8827 - val_loss: 0.0919 - val_accuracy: 0.8836
#
# Epoch 00050: val_accuracy did not improve from 0.88356
# Epoch 51/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0766 - accuracy: 0.8827 - val_loss: 0.0920 - val_accuracy: 0.8836
#
# Epoch 00051: val_accuracy did not improve from 0.88356
# Epoch 52/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0747 - accuracy: 0.8762 - val_loss: 0.0960 - val_accuracy: 0.8630
#
# Epoch 00052: val_accuracy did not improve from 0.88356
# Epoch 53/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0696 - accuracy: 0.8990 - val_loss: 0.0920 - val_accuracy: 0.8767
#
# Epoch 00053: val_accuracy did not improve from 0.88356
# Epoch 54/100
# 10/10 [==============================] - 1s 155ms/step - loss: 0.0726 - accuracy: 0.8860 - val_loss: 0.0965 - val_accuracy: 0.8493
#
# Epoch 00054: val_accuracy did not improve from 0.88356
# Epoch 55/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0641 - accuracy: 0.9088 - val_loss: 0.0928 - val_accuracy: 0.8836
#
# Epoch 00055: val_accuracy did not improve from 0.88356
# Epoch 56/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0677 - accuracy: 0.8990 - val_loss: 0.0905 - val_accuracy: 0.8836
#
# Epoch 00056: val_accuracy did not improve from 0.88356
# Epoch 57/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0654 - accuracy: 0.9088 - val_loss: 0.0922 - val_accuracy: 0.8836
#
# Epoch 00057: val_accuracy did not improve from 0.88356
# Epoch 58/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0654 - accuracy: 0.9088 - val_loss: 0.0924 - val_accuracy: 0.8767
#
# Epoch 00058: val_accuracy did not improve from 0.88356
# Epoch 59/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0674 - accuracy: 0.8893 - val_loss: 0.0918 - val_accuracy: 0.8767
#
# Epoch 00059: val_accuracy did not improve from 0.88356
# Epoch 60/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0627 - accuracy: 0.9121 - val_loss: 0.0899 - val_accuracy: 0.8836
#
# Epoch 00060: val_accuracy did not improve from 0.88356
# Epoch 61/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0607 - accuracy: 0.9088 - val_loss: 0.0967 - val_accuracy: 0.8630
#
# Epoch 00061: val_accuracy did not improve from 0.88356
# Epoch 62/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0598 - accuracy: 0.9153 - val_loss: 0.0907 - val_accuracy: 0.8767
#
# Epoch 00062: val_accuracy did not improve from 0.88356
# Epoch 63/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0636 - accuracy: 0.9186 - val_loss: 0.0919 - val_accuracy: 0.8630
#
# Epoch 00063: val_accuracy did not improve from 0.88356
# Epoch 64/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0650 - accuracy: 0.8958 - val_loss: 0.0936 - val_accuracy: 0.8562
#
# Epoch 00064: val_accuracy did not improve from 0.88356
# Epoch 65/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0630 - accuracy: 0.9153 - val_loss: 0.0902 - val_accuracy: 0.8699
#
# Epoch 00065: val_accuracy did not improve from 0.88356
# Epoch 66/100
# 10/10 [==============================] - 2s 152ms/step - loss: 0.0585 - accuracy: 0.9186 - val_loss: 0.0925 - val_accuracy: 0.8836
#
# Epoch 00066: val_accuracy did not improve from 0.88356
# Epoch 67/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0548 - accuracy: 0.9218 - val_loss: 0.0948 - val_accuracy: 0.8630
#
# Epoch 00067: val_accuracy did not improve from 0.88356
# Epoch 68/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.0545 - accuracy: 0.9218 - val_loss: 0.0950 - val_accuracy: 0.8699
#
# Epoch 00068: val_accuracy did not improve from 0.88356
# Epoch 69/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.0567 - accuracy: 0.9153 - val_loss: 0.0990 - val_accuracy: 0.8425
#
# Epoch 00069: val_accuracy did not improve from 0.88356
# Epoch 70/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0600 - accuracy: 0.9088 - val_loss: 0.0920 - val_accuracy: 0.8767
#
# Epoch 00070: val_accuracy did not improve from 0.88356
# Epoch 71/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0556 - accuracy: 0.9251 - val_loss: 0.0966 - val_accuracy: 0.8767
#
# Epoch 00071: val_accuracy did not improve from 0.88356
# Epoch 72/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0518 - accuracy: 0.9414 - val_loss: 0.0934 - val_accuracy: 0.8630
#
# Epoch 00072: val_accuracy did not improve from 0.88356
# Epoch 73/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.0556 - accuracy: 0.9218 - val_loss: 0.1038 - val_accuracy: 0.8425
#
# Epoch 00073: val_accuracy did not improve from 0.88356
# Epoch 74/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0555 - accuracy: 0.9218 - val_loss: 0.0925 - val_accuracy: 0.8836
#
# Epoch 00074: val_accuracy did not improve from 0.88356
# Epoch 75/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0556 - accuracy: 0.9187 - val_loss: 0.0985 - val_accuracy: 0.8493
#
# Epoch 00075: val_accuracy did not improve from 0.88356
# Epoch 76/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0549 - accuracy: 0.9153 - val_loss: 0.0913 - val_accuracy: 0.8767
#
# Epoch 00076: val_accuracy did not improve from 0.88356
# Epoch 77/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0569 - accuracy: 0.9186 - val_loss: 0.0954 - val_accuracy: 0.8630
#
# Epoch 00077: val_accuracy did not improve from 0.88356
# Epoch 78/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0528 - accuracy: 0.9186 - val_loss: 0.0959 - val_accuracy: 0.8562
#
# Epoch 00078: val_accuracy did not improve from 0.88356
# Epoch 79/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0509 - accuracy: 0.9186 - val_loss: 0.0948 - val_accuracy: 0.8699
#
# Epoch 00079: val_accuracy did not improve from 0.88356
# Epoch 80/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.0455 - accuracy: 0.9414 - val_loss: 0.0949 - val_accuracy: 0.8699
#
# Epoch 00080: val_accuracy did not improve from 0.88356
# Epoch 81/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.0508 - accuracy: 0.9316 - val_loss: 0.0929 - val_accuracy: 0.8767
#
# Epoch 00081: val_accuracy did not improve from 0.88356
# Epoch 82/100
# 10/10 [==============================] - 2s 177ms/step - loss: 0.0507 - accuracy: 0.9283 - val_loss: 0.1006 - val_accuracy: 0.8425
#
# Epoch 00082: val_accuracy did not improve from 0.88356
# Epoch 83/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0497 - accuracy: 0.9316 - val_loss: 0.0945 - val_accuracy: 0.8699
#
# Epoch 00083: val_accuracy did not improve from 0.88356
# Epoch 84/100
# 10/10 [==============================] - 2s 179ms/step - loss: 0.0490 - accuracy: 0.9344 - val_loss: 0.1019 - val_accuracy: 0.8493
#
# Epoch 00084: val_accuracy did not improve from 0.88356
# Epoch 85/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0471 - accuracy: 0.9218 - val_loss: 0.0947 - val_accuracy: 0.8836
#
# Epoch 00085: val_accuracy did not improve from 0.88356
# Epoch 86/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0460 - accuracy: 0.9381 - val_loss: 0.0974 - val_accuracy: 0.8767
#
# Epoch 00086: val_accuracy did not improve from 0.88356
# Epoch 87/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0464 - accuracy: 0.9446 - val_loss: 0.0973 - val_accuracy: 0.8630
#
# Epoch 00087: val_accuracy did not improve from 0.88356
# Epoch 88/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0445 - accuracy: 0.9414 - val_loss: 0.0956 - val_accuracy: 0.8767
#
# Epoch 00088: val_accuracy did not improve from 0.88356
# Epoch 89/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.0449 - accuracy: 0.9406 - val_loss: 0.1016 - val_accuracy: 0.8630
#
# Epoch 00089: val_accuracy did not improve from 0.88356
# Epoch 90/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0440 - accuracy: 0.9414 - val_loss: 0.0980 - val_accuracy: 0.8630
#
# Epoch 00090: val_accuracy did not improve from 0.88356
# Epoch 91/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0397 - accuracy: 0.9479 - val_loss: 0.0964 - val_accuracy: 0.8836
#
# Epoch 00091: val_accuracy did not improve from 0.88356
# Epoch 92/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.0448 - accuracy: 0.9283 - val_loss: 0.1005 - val_accuracy: 0.8562
#
# Epoch 00092: val_accuracy did not improve from 0.88356
# Epoch 93/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0413 - accuracy: 0.9511 - val_loss: 0.0946 - val_accuracy: 0.8630
#
# Epoch 00093: val_accuracy did not improve from 0.88356
# Epoch 94/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0410 - accuracy: 0.9511 - val_loss: 0.0965 - val_accuracy: 0.8767
#
# Epoch 00094: val_accuracy did not improve from 0.88356
# Epoch 95/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0416 - accuracy: 0.9414 - val_loss: 0.0957 - val_accuracy: 0.8699
#
# Epoch 00095: val_accuracy did not improve from 0.88356
# Epoch 96/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0382 - accuracy: 0.9609 - val_loss: 0.1037 - val_accuracy: 0.8493
#
# Epoch 00096: val_accuracy did not improve from 0.88356
# Epoch 97/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.0398 - accuracy: 0.9479 - val_loss: 0.0978 - val_accuracy: 0.8699
#
# Epoch 00097: val_accuracy did not improve from 0.88356
# Epoch 98/100
# 10/10 [==============================] - 2s 178ms/step - loss: 0.0397 - accuracy: 0.9479 - val_loss: 0.0942 - val_accuracy: 0.8767
#
# Epoch 00098: val_accuracy did not improve from 0.88356
# Epoch 99/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.0406 - accuracy: 0.9511 - val_loss: 0.0992 - val_accuracy: 0.8699
#
# Epoch 00099: val_accuracy did not improve from 0.88356
# Epoch 100/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.0371 - accuracy: 0.9577 - val_loss: 0.1008 - val_accuracy: 0.8699
#
# Epoch 00100: val_accuracy did not improve from 0.88356
# Best Validation Accuracy:0.8835616707801819
# *******Model Performance*************
# Test acc: 0.8835616438356164
# Precision:0.8888888888888888
# recall:0.9361702127659575
# f1:0.9119170984455959
# AUC:0.862315875613748
# Sensitivity:0.9361702127659575
# specificity:0.7884615384615384

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=64
WIDTH=64
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [5,7],filters=[32,64],strides=[1,2])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(32, 64, 64, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 60, 60, 32)          2432
# _________________________________________________________________
# conv1 (Conv2D)               (32, 27, 27, 64)          100416
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 11, 11, 64)          200768
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 968, 8)              0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 968, 8)              0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               247808
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 551,424
# Trainable params: 551,424
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 3s 211ms/step - loss: 0.5592 - accuracy: 0.6254 - val_loss: 0.2773 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.3028 - accuracy: 0.6482 - val_loss: 0.2905 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.2555 - accuracy: 0.6515 - val_loss: 0.2443 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.2390 - accuracy: 0.6482 - val_loss: 0.2392 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.2236 - accuracy: 0.6482 - val_loss: 0.2276 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.2146 - accuracy: 0.6482 - val_loss: 0.2240 - val_accuracy: 0.6438
#
# Epoch 00006: val_accuracy did not improve from 0.64384
# Epoch 7/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.2127 - accuracy: 0.6482 - val_loss: 0.2151 - val_accuracy: 0.6438
#
# Epoch 00007: val_accuracy did not improve from 0.64384
# Epoch 8/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.2051 - accuracy: 0.6482 - val_loss: 0.2064 - val_accuracy: 0.6438
#
# Epoch 00008: val_accuracy did not improve from 0.64384
# Epoch 9/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.1974 - accuracy: 0.6580 - val_loss: 0.1982 - val_accuracy: 0.6438
#
# Epoch 00009: val_accuracy did not improve from 0.64384
# Epoch 10/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1860 - accuracy: 0.6687 - val_loss: 0.1942 - val_accuracy: 0.6233
#
# Epoch 00010: val_accuracy did not improve from 0.64384
# Epoch 11/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.1883 - accuracy: 0.6515 - val_loss: 0.1967 - val_accuracy: 0.6575
#
# Epoch 00011: val_accuracy improved from 0.64384 to 0.65753, saving model to ./result\weights.h5
# Epoch 12/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.1802 - accuracy: 0.6775 - val_loss: 0.1858 - val_accuracy: 0.6575
#
# Epoch 00012: val_accuracy did not improve from 0.65753
# Epoch 13/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.1673 - accuracy: 0.6971 - val_loss: 0.1732 - val_accuracy: 0.6644
#
# Epoch 00013: val_accuracy improved from 0.65753 to 0.66438, saving model to ./result\weights.h5
# Epoch 14/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.1635 - accuracy: 0.7068 - val_loss: 0.1662 - val_accuracy: 0.6918
#
# Epoch 00014: val_accuracy improved from 0.66438 to 0.69178, saving model to ./result\weights.h5
# Epoch 15/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.1593 - accuracy: 0.7264 - val_loss: 0.1593 - val_accuracy: 0.6986
#
# Epoch 00015: val_accuracy improved from 0.69178 to 0.69863, saving model to ./result\weights.h5
# Epoch 16/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.1616 - accuracy: 0.7003 - val_loss: 0.1638 - val_accuracy: 0.7055
#
# Epoch 00016: val_accuracy improved from 0.69863 to 0.70548, saving model to ./result\weights.h5
# Epoch 17/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1391 - accuracy: 0.7492 - val_loss: 0.1430 - val_accuracy: 0.7671
#
# Epoch 00017: val_accuracy improved from 0.70548 to 0.76712, saving model to ./result\weights.h5
# Epoch 18/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1308 - accuracy: 0.7850 - val_loss: 0.1377 - val_accuracy: 0.7740
#
# Epoch 00018: val_accuracy improved from 0.76712 to 0.77397, saving model to ./result\weights.h5
# Epoch 19/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.1249 - accuracy: 0.7980 - val_loss: 0.1278 - val_accuracy: 0.7740
#
# Epoch 00019: val_accuracy did not improve from 0.77397
# Epoch 20/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.1210 - accuracy: 0.7785 - val_loss: 0.1259 - val_accuracy: 0.8082
#
# Epoch 00020: val_accuracy improved from 0.77397 to 0.80822, saving model to ./result\weights.h5
# Epoch 21/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.1173 - accuracy: 0.8111 - val_loss: 0.1208 - val_accuracy: 0.8014
#
# Epoch 00021: val_accuracy did not improve from 0.80822
# Epoch 22/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.1080 - accuracy: 0.8125 - val_loss: 0.1193 - val_accuracy: 0.8151
#
# Epoch 00022: val_accuracy improved from 0.80822 to 0.81507, saving model to ./result\weights.h5
# Epoch 23/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1103 - accuracy: 0.8143 - val_loss: 0.1135 - val_accuracy: 0.8151
#
# Epoch 00023: val_accuracy did not improve from 0.81507
# Epoch 24/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.1047 - accuracy: 0.8111 - val_loss: 0.1104 - val_accuracy: 0.8493
#
# Epoch 00024: val_accuracy improved from 0.81507 to 0.84932, saving model to ./result\weights.h5
# Epoch 25/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0998 - accuracy: 0.8404 - val_loss: 0.1066 - val_accuracy: 0.8493
#
# Epoch 00025: val_accuracy did not improve from 0.84932
# Epoch 26/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0950 - accuracy: 0.8371 - val_loss: 0.1081 - val_accuracy: 0.8493
#
# Epoch 00026: val_accuracy did not improve from 0.84932
# Epoch 27/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0917 - accuracy: 0.8599 - val_loss: 0.1051 - val_accuracy: 0.8699
#
# Epoch 00027: val_accuracy improved from 0.84932 to 0.86986, saving model to ./result\weights.h5
# Epoch 28/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0945 - accuracy: 0.8344 - val_loss: 0.1055 - val_accuracy: 0.8699
#
# Epoch 00028: val_accuracy did not improve from 0.86986
# Epoch 29/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0942 - accuracy: 0.8339 - val_loss: 0.1058 - val_accuracy: 0.8767
#
# Epoch 00029: val_accuracy improved from 0.86986 to 0.87671, saving model to ./result\weights.h5
# Epoch 30/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0951 - accuracy: 0.8599 - val_loss: 0.1094 - val_accuracy: 0.8288
#
# Epoch 00030: val_accuracy did not improve from 0.87671
# Epoch 31/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0916 - accuracy: 0.8469 - val_loss: 0.1052 - val_accuracy: 0.8699
#
# Epoch 00031: val_accuracy did not improve from 0.87671
# Epoch 32/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0905 - accuracy: 0.8502 - val_loss: 0.0978 - val_accuracy: 0.8767
#
# Epoch 00032: val_accuracy did not improve from 0.87671
# Epoch 33/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0854 - accuracy: 0.8502 - val_loss: 0.1045 - val_accuracy: 0.8699
#
# Epoch 00033: val_accuracy did not improve from 0.87671
# Epoch 34/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0816 - accuracy: 0.8795 - val_loss: 0.0985 - val_accuracy: 0.8767
#
# Epoch 00034: val_accuracy did not improve from 0.87671
# Epoch 35/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0818 - accuracy: 0.8762 - val_loss: 0.0975 - val_accuracy: 0.8699
#
# Epoch 00035: val_accuracy did not improve from 0.87671
# Epoch 36/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0786 - accuracy: 0.8730 - val_loss: 0.0986 - val_accuracy: 0.8630
#
# Epoch 00036: val_accuracy did not improve from 0.87671
# Epoch 37/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0886 - accuracy: 0.8502 - val_loss: 0.0967 - val_accuracy: 0.8699
#
# Epoch 00037: val_accuracy did not improve from 0.87671
# Epoch 38/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0797 - accuracy: 0.8795 - val_loss: 0.0947 - val_accuracy: 0.8699
#
# Epoch 00038: val_accuracy did not improve from 0.87671
# Epoch 39/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0749 - accuracy: 0.8795 - val_loss: 0.0964 - val_accuracy: 0.8699
#
# Epoch 00039: val_accuracy did not improve from 0.87671
# Epoch 40/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0782 - accuracy: 0.8730 - val_loss: 0.0946 - val_accuracy: 0.8699
#
# Epoch 00040: val_accuracy did not improve from 0.87671
# Epoch 41/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0787 - accuracy: 0.8730 - val_loss: 0.0941 - val_accuracy: 0.8836
#
# Epoch 00041: val_accuracy improved from 0.87671 to 0.88356, saving model to ./result\weights.h5
# Epoch 42/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0770 - accuracy: 0.8795 - val_loss: 0.0916 - val_accuracy: 0.8904
#
# Epoch 00042: val_accuracy improved from 0.88356 to 0.89041, saving model to ./result\weights.h5
# Epoch 43/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0715 - accuracy: 0.9088 - val_loss: 0.1001 - val_accuracy: 0.8699
#
# Epoch 00043: val_accuracy did not improve from 0.89041
# Epoch 44/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0758 - accuracy: 0.8730 - val_loss: 0.0920 - val_accuracy: 0.8699
#
# Epoch 00044: val_accuracy did not improve from 0.89041
# Epoch 45/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0745 - accuracy: 0.8827 - val_loss: 0.0959 - val_accuracy: 0.8767
#
# Epoch 00045: val_accuracy did not improve from 0.89041
# Epoch 46/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0724 - accuracy: 0.8860 - val_loss: 0.0913 - val_accuracy: 0.8767
#
# Epoch 00046: val_accuracy did not improve from 0.89041
# Epoch 47/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0727 - accuracy: 0.8990 - val_loss: 0.0922 - val_accuracy: 0.8767
#
# Epoch 00047: val_accuracy did not improve from 0.89041
# Epoch 48/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0758 - accuracy: 0.8860 - val_loss: 0.0942 - val_accuracy: 0.8767
#
# Epoch 00048: val_accuracy did not improve from 0.89041
# Epoch 49/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0701 - accuracy: 0.8958 - val_loss: 0.0914 - val_accuracy: 0.8767
#
# Epoch 00049: val_accuracy did not improve from 0.89041
# Epoch 50/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0690 - accuracy: 0.9055 - val_loss: 0.1002 - val_accuracy: 0.8699
#
# Epoch 00050: val_accuracy did not improve from 0.89041
# Epoch 51/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0749 - accuracy: 0.8958 - val_loss: 0.0939 - val_accuracy: 0.8562
#
# Epoch 00051: val_accuracy did not improve from 0.89041
# Epoch 52/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0733 - accuracy: 0.8925 - val_loss: 0.1014 - val_accuracy: 0.8767
#
# Epoch 00052: val_accuracy did not improve from 0.89041
# Epoch 53/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0666 - accuracy: 0.9023 - val_loss: 0.0922 - val_accuracy: 0.8630
#
# Epoch 00053: val_accuracy did not improve from 0.89041
# Epoch 54/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0689 - accuracy: 0.9023 - val_loss: 0.0962 - val_accuracy: 0.8630
#
# Epoch 00054: val_accuracy did not improve from 0.89041
# Epoch 55/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0630 - accuracy: 0.9153 - val_loss: 0.0942 - val_accuracy: 0.8767
#
# Epoch 00055: val_accuracy did not improve from 0.89041
# Epoch 56/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0663 - accuracy: 0.9055 - val_loss: 0.0903 - val_accuracy: 0.8699
#
# Epoch 00056: val_accuracy did not improve from 0.89041
# Epoch 57/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0634 - accuracy: 0.9023 - val_loss: 0.0909 - val_accuracy: 0.8836
#
# Epoch 00057: val_accuracy did not improve from 0.89041
# Epoch 58/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0636 - accuracy: 0.8990 - val_loss: 0.0970 - val_accuracy: 0.8630
#
# Epoch 00058: val_accuracy did not improve from 0.89041
# Epoch 59/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0665 - accuracy: 0.8925 - val_loss: 0.0915 - val_accuracy: 0.8630
#
# Epoch 00059: val_accuracy did not improve from 0.89041
# Epoch 60/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0625 - accuracy: 0.9088 - val_loss: 0.0905 - val_accuracy: 0.8767
#
# Epoch 00060: val_accuracy did not improve from 0.89041
# Epoch 61/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0584 - accuracy: 0.9121 - val_loss: 0.0969 - val_accuracy: 0.8562
#
# Epoch 00061: val_accuracy did not improve from 0.89041
# Epoch 62/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0587 - accuracy: 0.9121 - val_loss: 0.0914 - val_accuracy: 0.8562
#
# Epoch 00062: val_accuracy did not improve from 0.89041
# Epoch 63/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0619 - accuracy: 0.9088 - val_loss: 0.0925 - val_accuracy: 0.8699
#
# Epoch 00063: val_accuracy did not improve from 0.89041
# Epoch 64/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0640 - accuracy: 0.8860 - val_loss: 0.0995 - val_accuracy: 0.8356
#
# Epoch 00064: val_accuracy did not improve from 0.89041
# Epoch 65/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0625 - accuracy: 0.9023 - val_loss: 0.0935 - val_accuracy: 0.8630
#
# Epoch 00065: val_accuracy did not improve from 0.89041
# Epoch 66/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0604 - accuracy: 0.9153 - val_loss: 0.0930 - val_accuracy: 0.8630
#
# Epoch 00066: val_accuracy did not improve from 0.89041
# Epoch 67/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0564 - accuracy: 0.9186 - val_loss: 0.0966 - val_accuracy: 0.8425
#
# Epoch 00067: val_accuracy did not improve from 0.89041
# Epoch 68/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0538 - accuracy: 0.9251 - val_loss: 0.0999 - val_accuracy: 0.8493
#
# Epoch 00068: val_accuracy did not improve from 0.89041
# Epoch 69/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0567 - accuracy: 0.9186 - val_loss: 0.0980 - val_accuracy: 0.8562
#
# Epoch 00069: val_accuracy did not improve from 0.89041
# Epoch 70/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0587 - accuracy: 0.9055 - val_loss: 0.0926 - val_accuracy: 0.8630
#
# Epoch 00070: val_accuracy did not improve from 0.89041
# Epoch 71/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0544 - accuracy: 0.9153 - val_loss: 0.0997 - val_accuracy: 0.8562
#
# Epoch 00071: val_accuracy did not improve from 0.89041
# Epoch 72/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0512 - accuracy: 0.9153 - val_loss: 0.0975 - val_accuracy: 0.8493
#
# Epoch 00072: val_accuracy did not improve from 0.89041
# Epoch 73/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0556 - accuracy: 0.9055 - val_loss: 0.1106 - val_accuracy: 0.8219
#
# Epoch 00073: val_accuracy did not improve from 0.89041
# Epoch 74/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0534 - accuracy: 0.9283 - val_loss: 0.0958 - val_accuracy: 0.8699
#
# Epoch 00074: val_accuracy did not improve from 0.89041
# Epoch 75/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0566 - accuracy: 0.9219 - val_loss: 0.1018 - val_accuracy: 0.8356
#
# Epoch 00075: val_accuracy did not improve from 0.89041
# Epoch 76/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0558 - accuracy: 0.9153 - val_loss: 0.0998 - val_accuracy: 0.8493
#
# Epoch 00076: val_accuracy did not improve from 0.89041
# Epoch 77/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0561 - accuracy: 0.9055 - val_loss: 0.0987 - val_accuracy: 0.8425
#
# Epoch 00077: val_accuracy did not improve from 0.89041
# Epoch 78/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0538 - accuracy: 0.9186 - val_loss: 0.1015 - val_accuracy: 0.8562
#
# Epoch 00078: val_accuracy did not improve from 0.89041
# Epoch 79/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0504 - accuracy: 0.9218 - val_loss: 0.1037 - val_accuracy: 0.8562
#
# Epoch 00079: val_accuracy did not improve from 0.89041
# Epoch 80/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0460 - accuracy: 0.9316 - val_loss: 0.0972 - val_accuracy: 0.8493
#
# Epoch 00080: val_accuracy did not improve from 0.89041
# Epoch 81/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0525 - accuracy: 0.9153 - val_loss: 0.0995 - val_accuracy: 0.8562
#
# Epoch 00081: val_accuracy did not improve from 0.89041
# Epoch 82/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0533 - accuracy: 0.9186 - val_loss: 0.1094 - val_accuracy: 0.8219
#
# Epoch 00082: val_accuracy did not improve from 0.89041
# Epoch 83/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0509 - accuracy: 0.9283 - val_loss: 0.1017 - val_accuracy: 0.8425
#
# Epoch 00083: val_accuracy did not improve from 0.89041
# Epoch 84/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0489 - accuracy: 0.9250 - val_loss: 0.1070 - val_accuracy: 0.8425
#
# Epoch 00084: val_accuracy did not improve from 0.89041
# Epoch 85/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0476 - accuracy: 0.9218 - val_loss: 0.1074 - val_accuracy: 0.8493
#
# Epoch 00085: val_accuracy did not improve from 0.89041
# Epoch 86/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0465 - accuracy: 0.9414 - val_loss: 0.1049 - val_accuracy: 0.8562
#
# Epoch 00086: val_accuracy did not improve from 0.89041
# Epoch 87/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0479 - accuracy: 0.9316 - val_loss: 0.1049 - val_accuracy: 0.8562
#
# Epoch 00087: val_accuracy did not improve from 0.89041
# Epoch 88/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0464 - accuracy: 0.9349 - val_loss: 0.1021 - val_accuracy: 0.8562
#
# Epoch 00088: val_accuracy did not improve from 0.89041
# Epoch 89/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0456 - accuracy: 0.9344 - val_loss: 0.1094 - val_accuracy: 0.8493
#
# Epoch 00089: val_accuracy did not improve from 0.89041
# Epoch 90/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0441 - accuracy: 0.9414 - val_loss: 0.1057 - val_accuracy: 0.8562
#
# Epoch 00090: val_accuracy did not improve from 0.89041
# Epoch 91/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0427 - accuracy: 0.9381 - val_loss: 0.1035 - val_accuracy: 0.8562
#
# Epoch 00091: val_accuracy did not improve from 0.89041
# Epoch 92/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0459 - accuracy: 0.9316 - val_loss: 0.1062 - val_accuracy: 0.8493
#
# Epoch 00092: val_accuracy did not improve from 0.89041
# Epoch 93/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0437 - accuracy: 0.9349 - val_loss: 0.1016 - val_accuracy: 0.8630
#
# Epoch 00093: val_accuracy did not improve from 0.89041
# Epoch 94/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0428 - accuracy: 0.9381 - val_loss: 0.1070 - val_accuracy: 0.8630
#
# Epoch 00094: val_accuracy did not improve from 0.89041
# Epoch 95/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0418 - accuracy: 0.9381 - val_loss: 0.1028 - val_accuracy: 0.8493
#
# Epoch 00095: val_accuracy did not improve from 0.89041
# Epoch 96/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0410 - accuracy: 0.9544 - val_loss: 0.1161 - val_accuracy: 0.8288
#
# Epoch 00096: val_accuracy did not improve from 0.89041
# Epoch 97/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0424 - accuracy: 0.9446 - val_loss: 0.1091 - val_accuracy: 0.8493
#
# Epoch 00097: val_accuracy did not improve from 0.89041
# Epoch 98/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0414 - accuracy: 0.9446 - val_loss: 0.1032 - val_accuracy: 0.8562
#
# Epoch 00098: val_accuracy did not improve from 0.89041
# Epoch 99/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0426 - accuracy: 0.9511 - val_loss: 0.1059 - val_accuracy: 0.8562
#
# Epoch 00099: val_accuracy did not improve from 0.89041
# Epoch 100/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0380 - accuracy: 0.9544 - val_loss: 0.1093 - val_accuracy: 0.8493
#
# Epoch 00100: val_accuracy did not improve from 0.89041
# Best Validation Accuracy:0.8904109597206116
# *******Model Performance*************
# Test acc: 0.8904109589041096
# Precision:0.8823529411764706
# recall:0.9574468085106383
# f1:0.9183673469387754
# AUC:0.8633387888707038
# Sensitivity:0.9574468085106383
# specificity:0.7692307692307693

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=64
WIDTH=64
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [5,7,9],filters=[32,64,128],strides=[1,2,2])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(32, 64, 64, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 60, 60, 32)          2432
# _________________________________________________________________
# conv1 (Conv2D)               (32, 27, 27, 64)          100416
# _________________________________________________________________
# conv2 (Conv2D)               (32, 10, 10, 128)         663680
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 1, 1, 128)           1327232
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 16, 8)               0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 16, 8)               0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               4096
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 2,097,856
# Trainable params: 2,097,856
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 2s 122ms/step - loss: 0.6185 - accuracy: 0.5928 - val_loss: 0.2591 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.2264 - accuracy: 0.6482 - val_loss: 0.2101 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.2052 - accuracy: 0.6515 - val_loss: 0.2032 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.2011 - accuracy: 0.6482 - val_loss: 0.2003 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1987 - accuracy: 0.6482 - val_loss: 0.1989 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1975 - accuracy: 0.6482 - val_loss: 0.1979 - val_accuracy: 0.6438
#
# Epoch 00006: val_accuracy did not improve from 0.64384
# Epoch 7/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1966 - accuracy: 0.6482 - val_loss: 0.1972 - val_accuracy: 0.6438
#
# Epoch 00007: val_accuracy did not improve from 0.64384
# Epoch 8/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1956 - accuracy: 0.6482 - val_loss: 0.1964 - val_accuracy: 0.6438
#
# Epoch 00008: val_accuracy did not improve from 0.64384
# Epoch 9/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1960 - accuracy: 0.6417 - val_loss: 0.1953 - val_accuracy: 0.6438
#
# Epoch 00009: val_accuracy did not improve from 0.64384
# Epoch 10/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1921 - accuracy: 0.6500 - val_loss: 0.1931 - val_accuracy: 0.6438
#
# Epoch 00010: val_accuracy did not improve from 0.64384
# Epoch 11/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1898 - accuracy: 0.6450 - val_loss: 0.1892 - val_accuracy: 0.6438
#
# Epoch 00011: val_accuracy did not improve from 0.64384
# Epoch 12/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1814 - accuracy: 0.6547 - val_loss: 0.1871 - val_accuracy: 0.6575
#
# Epoch 00012: val_accuracy improved from 0.64384 to 0.65753, saving model to ./result\weights.h5
# Epoch 13/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1739 - accuracy: 0.6840 - val_loss: 0.1817 - val_accuracy: 0.6507
#
# Epoch 00013: val_accuracy did not improve from 0.65753
# Epoch 14/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1706 - accuracy: 0.6840 - val_loss: 0.1788 - val_accuracy: 0.6370
#
# Epoch 00014: val_accuracy did not improve from 0.65753
# Epoch 15/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1640 - accuracy: 0.6971 - val_loss: 0.1726 - val_accuracy: 0.6644
#
# Epoch 00015: val_accuracy improved from 0.65753 to 0.66438, saving model to ./result\weights.h5
# Epoch 16/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.1653 - accuracy: 0.6971 - val_loss: 0.1659 - val_accuracy: 0.6918
#
# Epoch 00016: val_accuracy improved from 0.66438 to 0.69178, saving model to ./result\weights.h5
# Epoch 17/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1534 - accuracy: 0.7231 - val_loss: 0.1600 - val_accuracy: 0.7260
#
# Epoch 00017: val_accuracy improved from 0.69178 to 0.72603, saving model to ./result\weights.h5
# Epoch 18/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1517 - accuracy: 0.7068 - val_loss: 0.1561 - val_accuracy: 0.7055
#
# Epoch 00018: val_accuracy did not improve from 0.72603
# Epoch 19/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1463 - accuracy: 0.7264 - val_loss: 0.1448 - val_accuracy: 0.7603
#
# Epoch 00019: val_accuracy improved from 0.72603 to 0.76027, saving model to ./result\weights.h5
# Epoch 20/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1377 - accuracy: 0.7557 - val_loss: 0.1399 - val_accuracy: 0.7740
#
# Epoch 00020: val_accuracy improved from 0.76027 to 0.77397, saving model to ./result\weights.h5
# Epoch 21/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1354 - accuracy: 0.7492 - val_loss: 0.1354 - val_accuracy: 0.8151
#
# Epoch 00021: val_accuracy improved from 0.77397 to 0.81507, saving model to ./result\weights.h5
# Epoch 22/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1257 - accuracy: 0.8000 - val_loss: 0.1253 - val_accuracy: 0.8151
#
# Epoch 00022: val_accuracy did not improve from 0.81507
# Epoch 23/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1242 - accuracy: 0.8274 - val_loss: 0.1228 - val_accuracy: 0.8288
#
# Epoch 00023: val_accuracy improved from 0.81507 to 0.82877, saving model to ./result\weights.h5
# Epoch 24/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1227 - accuracy: 0.8143 - val_loss: 0.1240 - val_accuracy: 0.8356
#
# Epoch 00024: val_accuracy improved from 0.82877 to 0.83562, saving model to ./result\weights.h5
# Epoch 25/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1141 - accuracy: 0.8404 - val_loss: 0.1122 - val_accuracy: 0.8493
#
# Epoch 00025: val_accuracy improved from 0.83562 to 0.84932, saving model to ./result\weights.h5
# Epoch 26/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1046 - accuracy: 0.8339 - val_loss: 0.1072 - val_accuracy: 0.8699
#
# Epoch 00026: val_accuracy improved from 0.84932 to 0.86986, saving model to ./result\weights.h5
# Epoch 27/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0976 - accuracy: 0.8502 - val_loss: 0.1075 - val_accuracy: 0.8699
#
# Epoch 00027: val_accuracy did not improve from 0.86986
# Epoch 28/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1000 - accuracy: 0.8531 - val_loss: 0.1013 - val_accuracy: 0.8630
#
# Epoch 00028: val_accuracy did not improve from 0.86986
# Epoch 29/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1036 - accuracy: 0.8469 - val_loss: 0.1176 - val_accuracy: 0.8288
#
# Epoch 00029: val_accuracy did not improve from 0.86986
# Epoch 30/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1017 - accuracy: 0.8664 - val_loss: 0.1123 - val_accuracy: 0.8562
#
# Epoch 00030: val_accuracy did not improve from 0.86986
# Epoch 31/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0920 - accuracy: 0.8762 - val_loss: 0.1041 - val_accuracy: 0.8562
#
# Epoch 00031: val_accuracy did not improve from 0.86986
# Epoch 32/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0919 - accuracy: 0.8502 - val_loss: 0.0919 - val_accuracy: 0.8904
#
# Epoch 00032: val_accuracy improved from 0.86986 to 0.89041, saving model to ./result\weights.h5
# Epoch 33/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0871 - accuracy: 0.8762 - val_loss: 0.0931 - val_accuracy: 0.8699
#
# Epoch 00033: val_accuracy did not improve from 0.89041
# Epoch 34/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0814 - accuracy: 0.8730 - val_loss: 0.0904 - val_accuracy: 0.8699
#
# Epoch 00034: val_accuracy did not improve from 0.89041
# Epoch 35/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0812 - accuracy: 0.8925 - val_loss: 0.0899 - val_accuracy: 0.8699
#
# Epoch 00035: val_accuracy did not improve from 0.89041
# Epoch 36/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0798 - accuracy: 0.8827 - val_loss: 0.0931 - val_accuracy: 0.8767
#
# Epoch 00036: val_accuracy did not improve from 0.89041
# Epoch 37/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0883 - accuracy: 0.8632 - val_loss: 0.0906 - val_accuracy: 0.8767
#
# Epoch 00037: val_accuracy did not improve from 0.89041
# Epoch 38/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0826 - accuracy: 0.8599 - val_loss: 0.0883 - val_accuracy: 0.8836
#
# Epoch 00038: val_accuracy did not improve from 0.89041
# Epoch 39/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0752 - accuracy: 0.8860 - val_loss: 0.0917 - val_accuracy: 0.8767
#
# Epoch 00039: val_accuracy did not improve from 0.89041
# Epoch 40/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0798 - accuracy: 0.8632 - val_loss: 0.0861 - val_accuracy: 0.8836
#
# Epoch 00040: val_accuracy did not improve from 0.89041
# Epoch 41/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0797 - accuracy: 0.8730 - val_loss: 0.0900 - val_accuracy: 0.8767
#
# Epoch 00041: val_accuracy did not improve from 0.89041
# Epoch 42/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0792 - accuracy: 0.8827 - val_loss: 0.0848 - val_accuracy: 0.8904
#
# Epoch 00042: val_accuracy did not improve from 0.89041
# Epoch 43/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0693 - accuracy: 0.8893 - val_loss: 0.0934 - val_accuracy: 0.8630
#
# Epoch 00043: val_accuracy did not improve from 0.89041
# Epoch 44/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0765 - accuracy: 0.8893 - val_loss: 0.0843 - val_accuracy: 0.8836
#
# Epoch 00044: val_accuracy did not improve from 0.89041
# Epoch 45/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0748 - accuracy: 0.8860 - val_loss: 0.0894 - val_accuracy: 0.8699
#
# Epoch 00045: val_accuracy did not improve from 0.89041
# Epoch 46/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0741 - accuracy: 0.8893 - val_loss: 0.0841 - val_accuracy: 0.8836
#
# Epoch 00046: val_accuracy did not improve from 0.89041
# Epoch 47/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0742 - accuracy: 0.8925 - val_loss: 0.0858 - val_accuracy: 0.8699
#
# Epoch 00047: val_accuracy did not improve from 0.89041
# Epoch 48/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0786 - accuracy: 0.8697 - val_loss: 0.0875 - val_accuracy: 0.8836
#
# Epoch 00048: val_accuracy did not improve from 0.89041
# Epoch 49/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0712 - accuracy: 0.8990 - val_loss: 0.0860 - val_accuracy: 0.8767
#
# Epoch 00049: val_accuracy did not improve from 0.89041
# Epoch 50/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0733 - accuracy: 0.8925 - val_loss: 0.0863 - val_accuracy: 0.8767
#
# Epoch 00050: val_accuracy did not improve from 0.89041
# Epoch 51/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0733 - accuracy: 0.8925 - val_loss: 0.0853 - val_accuracy: 0.8904
#
# Epoch 00051: val_accuracy did not improve from 0.89041
# Epoch 52/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0737 - accuracy: 0.8860 - val_loss: 0.0873 - val_accuracy: 0.8699
#
# Epoch 00052: val_accuracy did not improve from 0.89041
# Epoch 53/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0676 - accuracy: 0.9186 - val_loss: 0.0846 - val_accuracy: 0.8836
#
# Epoch 00053: val_accuracy did not improve from 0.89041
# Epoch 54/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0702 - accuracy: 0.8860 - val_loss: 0.0882 - val_accuracy: 0.8630
#
# Epoch 00054: val_accuracy did not improve from 0.89041
# Epoch 55/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0573 - accuracy: 0.9251 - val_loss: 0.0849 - val_accuracy: 0.8904
#
# Epoch 00055: val_accuracy did not improve from 0.89041
# Epoch 56/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0630 - accuracy: 0.9088 - val_loss: 0.0842 - val_accuracy: 0.8836
#
# Epoch 00056: val_accuracy did not improve from 0.89041
# Epoch 57/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0618 - accuracy: 0.9186 - val_loss: 0.0837 - val_accuracy: 0.9041
#
# Epoch 00057: val_accuracy improved from 0.89041 to 0.90411, saving model to ./result\weights.h5
# Epoch 58/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0612 - accuracy: 0.9088 - val_loss: 0.0881 - val_accuracy: 0.8767
#
# Epoch 00058: val_accuracy did not improve from 0.90411
# Epoch 59/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0631 - accuracy: 0.9055 - val_loss: 0.0881 - val_accuracy: 0.8836
#
# Epoch 00059: val_accuracy did not improve from 0.90411
# Epoch 60/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0592 - accuracy: 0.9186 - val_loss: 0.0852 - val_accuracy: 0.8973
#
# Epoch 00060: val_accuracy did not improve from 0.90411
# Epoch 61/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0532 - accuracy: 0.9251 - val_loss: 0.0899 - val_accuracy: 0.8699
#
# Epoch 00061: val_accuracy did not improve from 0.90411
# Epoch 62/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0550 - accuracy: 0.9153 - val_loss: 0.0861 - val_accuracy: 0.8973
#
# Epoch 00062: val_accuracy did not improve from 0.90411
# Epoch 63/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0557 - accuracy: 0.9218 - val_loss: 0.0885 - val_accuracy: 0.8904
#
# Epoch 00063: val_accuracy did not improve from 0.90411
# Epoch 64/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0563 - accuracy: 0.9186 - val_loss: 0.0939 - val_accuracy: 0.8699
#
# Epoch 00064: val_accuracy did not improve from 0.90411
# Epoch 65/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0554 - accuracy: 0.9218 - val_loss: 0.0872 - val_accuracy: 0.8904
#
# Epoch 00065: val_accuracy did not improve from 0.90411
# Epoch 66/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0536 - accuracy: 0.9251 - val_loss: 0.0895 - val_accuracy: 0.8904
#
# Epoch 00066: val_accuracy did not improve from 0.90411
# Epoch 67/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0513 - accuracy: 0.9251 - val_loss: 0.0905 - val_accuracy: 0.8699
#
# Epoch 00067: val_accuracy did not improve from 0.90411
# Epoch 68/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0489 - accuracy: 0.9283 - val_loss: 0.0935 - val_accuracy: 0.8699
#
# Epoch 00068: val_accuracy did not improve from 0.90411
# Epoch 69/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0533 - accuracy: 0.9251 - val_loss: 0.0929 - val_accuracy: 0.8699
#
# Epoch 00069: val_accuracy did not improve from 0.90411
# Epoch 70/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0533 - accuracy: 0.9218 - val_loss: 0.0889 - val_accuracy: 0.8973
#
# Epoch 00070: val_accuracy did not improve from 0.90411
# Epoch 71/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0477 - accuracy: 0.9414 - val_loss: 0.0931 - val_accuracy: 0.8767
#
# Epoch 00071: val_accuracy did not improve from 0.90411
# Epoch 72/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0458 - accuracy: 0.9446 - val_loss: 0.0915 - val_accuracy: 0.8973
#
# Epoch 00072: val_accuracy did not improve from 0.90411
# Epoch 73/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0465 - accuracy: 0.9283 - val_loss: 0.0984 - val_accuracy: 0.8630
#
# Epoch 00073: val_accuracy did not improve from 0.90411
# Epoch 74/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0520 - accuracy: 0.9153 - val_loss: 0.0898 - val_accuracy: 0.8836
#
# Epoch 00074: val_accuracy did not improve from 0.90411
# Epoch 75/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0499 - accuracy: 0.9250 - val_loss: 0.0939 - val_accuracy: 0.8767
#
# Epoch 00075: val_accuracy did not improve from 0.90411
# Epoch 76/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0504 - accuracy: 0.9349 - val_loss: 0.0889 - val_accuracy: 0.8836
#
# Epoch 00076: val_accuracy did not improve from 0.90411
# Epoch 77/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0501 - accuracy: 0.9251 - val_loss: 0.0928 - val_accuracy: 0.8836
#
# Epoch 00077: val_accuracy did not improve from 0.90411
# Epoch 78/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0445 - accuracy: 0.9349 - val_loss: 0.0916 - val_accuracy: 0.8904
#
# Epoch 00078: val_accuracy did not improve from 0.90411
# Epoch 79/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0403 - accuracy: 0.9414 - val_loss: 0.0918 - val_accuracy: 0.8904
#
# Epoch 00079: val_accuracy did not improve from 0.90411
# Epoch 80/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0354 - accuracy: 0.9577 - val_loss: 0.0941 - val_accuracy: 0.8904
#
# Epoch 00080: val_accuracy did not improve from 0.90411
# Epoch 81/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0422 - accuracy: 0.9381 - val_loss: 0.0925 - val_accuracy: 0.8904
#
# Epoch 00081: val_accuracy did not improve from 0.90411
# Epoch 82/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0447 - accuracy: 0.9414 - val_loss: 0.0959 - val_accuracy: 0.8630
#
# Epoch 00082: val_accuracy did not improve from 0.90411
# Epoch 83/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.0420 - accuracy: 0.9316 - val_loss: 0.0955 - val_accuracy: 0.8973
#
# Epoch 00083: val_accuracy did not improve from 0.90411
# Epoch 84/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0380 - accuracy: 0.9469 - val_loss: 0.0934 - val_accuracy: 0.8767
#
# Epoch 00084: val_accuracy did not improve from 0.90411
# Epoch 85/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0374 - accuracy: 0.9446 - val_loss: 0.0933 - val_accuracy: 0.8973
#
# Epoch 00085: val_accuracy did not improve from 0.90411
# Epoch 86/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0353 - accuracy: 0.9511 - val_loss: 0.0934 - val_accuracy: 0.8973
#
# Epoch 00086: val_accuracy did not improve from 0.90411
# Epoch 87/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0372 - accuracy: 0.9381 - val_loss: 0.0959 - val_accuracy: 0.8767
#
# Epoch 00087: val_accuracy did not improve from 0.90411
# Epoch 88/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0367 - accuracy: 0.9479 - val_loss: 0.0932 - val_accuracy: 0.8904
#
# Epoch 00088: val_accuracy did not improve from 0.90411
# Epoch 89/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0350 - accuracy: 0.9438 - val_loss: 0.0948 - val_accuracy: 0.8904
#
# Epoch 00089: val_accuracy did not improve from 0.90411
# Epoch 90/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0337 - accuracy: 0.9446 - val_loss: 0.0928 - val_accuracy: 0.8904
#
# Epoch 00090: val_accuracy did not improve from 0.90411
# Epoch 91/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0309 - accuracy: 0.9511 - val_loss: 0.0954 - val_accuracy: 0.8836
#
# Epoch 00091: val_accuracy did not improve from 0.90411
# Epoch 92/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0341 - accuracy: 0.9414 - val_loss: 0.0938 - val_accuracy: 0.8973
#
# Epoch 00092: val_accuracy did not improve from 0.90411
# Epoch 93/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0303 - accuracy: 0.9577 - val_loss: 0.0940 - val_accuracy: 0.8904
#
# Epoch 00093: val_accuracy did not improve from 0.90411
# Epoch 94/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0313 - accuracy: 0.9511 - val_loss: 0.0952 - val_accuracy: 0.8767
#
# Epoch 00094: val_accuracy did not improve from 0.90411
# Epoch 95/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0332 - accuracy: 0.9479 - val_loss: 0.0940 - val_accuracy: 0.8836
#
# Epoch 00095: val_accuracy did not improve from 0.90411
# Epoch 96/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0297 - accuracy: 0.9577 - val_loss: 0.0958 - val_accuracy: 0.8767
#
# Epoch 00096: val_accuracy did not improve from 0.90411
# Epoch 97/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0289 - accuracy: 0.9544 - val_loss: 0.0935 - val_accuracy: 0.8836
#
# Epoch 00097: val_accuracy did not improve from 0.90411
# Epoch 98/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0323 - accuracy: 0.9446 - val_loss: 0.0945 - val_accuracy: 0.8767
#
# Epoch 00098: val_accuracy did not improve from 0.90411
# Epoch 99/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0320 - accuracy: 0.9577 - val_loss: 0.0962 - val_accuracy: 0.8630
#
# Epoch 00099: val_accuracy did not improve from 0.90411
# Epoch 100/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0288 - accuracy: 0.9577 - val_loss: 0.0957 - val_accuracy: 0.8836
#
# Epoch 00100: val_accuracy did not improve from 0.90411
# Best Validation Accuracy:0.9041095972061157
# *******Model Performance*************
# Test acc: 0.9041095890410958
# Precision:0.9081632653061225
# recall:0.9468085106382979
# f1:0.9270833333333334
# AUC:0.8868657937806873
# Sensitivity:0.9468085106382979
# specificity:0.8269230769230769

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=128
WIDTH=128
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [7],filters=[128],strides=[2])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(32, 128, 128, 3)]       0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 61, 61, 128)         18944
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 28, 28, 128)         802944
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 12544, 8)            0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 12544, 8)            0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               3211264
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 4,033,152
# Trainable params: 4,033,152
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 4s 268ms/step - loss: 0.4440 - accuracy: 0.4658 - val_loss: 0.2878 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/100
# 10/10 [==============================] - 2s 186ms/step - loss: 0.2892 - accuracy: 0.6482 - val_loss: 0.2723 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/100
# 10/10 [==============================] - 2s 186ms/step - loss: 0.2517 - accuracy: 0.6515 - val_loss: 0.2589 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/100
# 10/10 [==============================] - 2s 186ms/step - loss: 0.2389 - accuracy: 0.6482 - val_loss: 0.2441 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/100
# 10/10 [==============================] - 2s 185ms/step - loss: 0.2337 - accuracy: 0.6482 - val_loss: 0.2381 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/100
# 10/10 [==============================] - 2s 186ms/step - loss: 0.2163 - accuracy: 0.6612 - val_loss: 0.2264 - val_accuracy: 0.6233
#
# Epoch 00006: val_accuracy did not improve from 0.64384
# Epoch 7/100
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2142 - accuracy: 0.6515 - val_loss: 0.2143 - val_accuracy: 0.6438
#
# Epoch 00007: val_accuracy did not improve from 0.64384
# Epoch 8/100
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2048 - accuracy: 0.6710 - val_loss: 0.1980 - val_accuracy: 0.6849
#
# Epoch 00008: val_accuracy improved from 0.64384 to 0.68493, saving model to ./result\weights.h5
# Epoch 9/100
# 10/10 [==============================] - 2s 192ms/step - loss: 0.1970 - accuracy: 0.6612 - val_loss: 0.2022 - val_accuracy: 0.6438
#
# Epoch 00009: val_accuracy did not improve from 0.68493
# Epoch 10/100
# 10/10 [==============================] - 2s 193ms/step - loss: 0.1787 - accuracy: 0.6906 - val_loss: 0.1735 - val_accuracy: 0.6986
#
# Epoch 00010: val_accuracy improved from 0.68493 to 0.69863, saving model to ./result\weights.h5
# Epoch 11/100
# 10/10 [==============================] - 2s 188ms/step - loss: 0.1682 - accuracy: 0.7036 - val_loss: 0.1594 - val_accuracy: 0.7603
#
# Epoch 00011: val_accuracy improved from 0.69863 to 0.76027, saving model to ./result\weights.h5
# Epoch 12/100
# 10/10 [==============================] - 2s 186ms/step - loss: 0.1495 - accuracy: 0.7655 - val_loss: 0.1383 - val_accuracy: 0.8082
#
# Epoch 00012: val_accuracy improved from 0.76027 to 0.80822, saving model to ./result\weights.h5
# Epoch 13/100
# 10/10 [==============================] - 2s 188ms/step - loss: 0.1262 - accuracy: 0.8274 - val_loss: 0.1350 - val_accuracy: 0.8356
#
# Epoch 00013: val_accuracy improved from 0.80822 to 0.83562, saving model to ./result\weights.h5
# Epoch 14/100
# 10/10 [==============================] - 2s 195ms/step - loss: 0.1196 - accuracy: 0.8143 - val_loss: 0.1564 - val_accuracy: 0.7740
#
# Epoch 00014: val_accuracy did not improve from 0.83562
# Epoch 15/100
# 10/10 [==============================] - 2s 211ms/step - loss: 0.1157 - accuracy: 0.8534 - val_loss: 0.1352 - val_accuracy: 0.8425
#
# Epoch 00015: val_accuracy improved from 0.83562 to 0.84247, saving model to ./result\weights.h5
# Epoch 16/100
# 10/10 [==============================] - 2s 213ms/step - loss: 0.1386 - accuracy: 0.7850 - val_loss: 0.1333 - val_accuracy: 0.8630
#
# Epoch 00016: val_accuracy improved from 0.84247 to 0.86301, saving model to ./result\weights.h5
# Epoch 17/100
# 10/10 [==============================] - 2s 216ms/step - loss: 0.1134 - accuracy: 0.8436 - val_loss: 0.1177 - val_accuracy: 0.8562
#
# Epoch 00017: val_accuracy did not improve from 0.86301
# Epoch 18/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.1033 - accuracy: 0.8664 - val_loss: 0.1192 - val_accuracy: 0.8288
#
# Epoch 00018: val_accuracy did not improve from 0.86301
# Epoch 19/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0927 - accuracy: 0.8730 - val_loss: 0.1131 - val_accuracy: 0.8493
#
# Epoch 00019: val_accuracy did not improve from 0.86301
# Epoch 20/100
# 10/10 [==============================] - 2s 216ms/step - loss: 0.1012 - accuracy: 0.8730 - val_loss: 0.1151 - val_accuracy: 0.8562
#
# Epoch 00020: val_accuracy did not improve from 0.86301
# Epoch 21/100
# 10/10 [==============================] - 2s 224ms/step - loss: 0.0977 - accuracy: 0.8599 - val_loss: 0.1102 - val_accuracy: 0.8630
#
# Epoch 00021: val_accuracy did not improve from 0.86301
# Epoch 22/100
# 10/10 [==============================] - 2s 228ms/step - loss: 0.0881 - accuracy: 0.8938 - val_loss: 0.1058 - val_accuracy: 0.8699
#
# Epoch 00022: val_accuracy improved from 0.86301 to 0.86986, saving model to ./result\weights.h5
# Epoch 23/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0864 - accuracy: 0.8730 - val_loss: 0.1026 - val_accuracy: 0.8699
#
# Epoch 00023: val_accuracy did not improve from 0.86986
# Epoch 24/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0866 - accuracy: 0.8762 - val_loss: 0.1086 - val_accuracy: 0.8699
#
# Epoch 00024: val_accuracy did not improve from 0.86986
# Epoch 25/100
# 10/10 [==============================] - 2s 222ms/step - loss: 0.0796 - accuracy: 0.9023 - val_loss: 0.0972 - val_accuracy: 0.8699
#
# Epoch 00025: val_accuracy did not improve from 0.86986
# Epoch 26/100
# 10/10 [==============================] - 2s 225ms/step - loss: 0.0728 - accuracy: 0.8925 - val_loss: 0.1001 - val_accuracy: 0.8699
#
# Epoch 00026: val_accuracy did not improve from 0.86986
# Epoch 27/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0752 - accuracy: 0.8990 - val_loss: 0.0928 - val_accuracy: 0.8904
#
# Epoch 00027: val_accuracy improved from 0.86986 to 0.89041, saving model to ./result\weights.h5
# Epoch 28/100
# 10/10 [==============================] - 2s 224ms/step - loss: 0.0748 - accuracy: 0.8906 - val_loss: 0.1052 - val_accuracy: 0.8425
#
# Epoch 00028: val_accuracy did not improve from 0.89041
# Epoch 29/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0747 - accuracy: 0.9153 - val_loss: 0.1002 - val_accuracy: 0.8767
#
# Epoch 00029: val_accuracy did not improve from 0.89041
# Epoch 30/100
# 10/10 [==============================] - 2s 220ms/step - loss: 0.0835 - accuracy: 0.8860 - val_loss: 0.1021 - val_accuracy: 0.8630
#
# Epoch 00030: val_accuracy did not improve from 0.89041
# Epoch 31/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0800 - accuracy: 0.8925 - val_loss: 0.1009 - val_accuracy: 0.8630
#
# Epoch 00031: val_accuracy did not improve from 0.89041
# Epoch 32/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0708 - accuracy: 0.9088 - val_loss: 0.0955 - val_accuracy: 0.8767
#
# Epoch 00032: val_accuracy did not improve from 0.89041
# Epoch 33/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0668 - accuracy: 0.8990 - val_loss: 0.0952 - val_accuracy: 0.8767
#
# Epoch 00033: val_accuracy did not improve from 0.89041
# Epoch 34/100
# 10/10 [==============================] - 2s 218ms/step - loss: 0.0637 - accuracy: 0.9349 - val_loss: 0.0999 - val_accuracy: 0.8973
#
# Epoch 00034: val_accuracy improved from 0.89041 to 0.89726, saving model to ./result\weights.h5
# Epoch 35/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0681 - accuracy: 0.9153 - val_loss: 0.1074 - val_accuracy: 0.8699
#
# Epoch 00035: val_accuracy did not improve from 0.89726
# Epoch 36/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0655 - accuracy: 0.9218 - val_loss: 0.1003 - val_accuracy: 0.8836
#
# Epoch 00036: val_accuracy did not improve from 0.89726
# Epoch 37/100
# 10/10 [==============================] - 2s 218ms/step - loss: 0.0677 - accuracy: 0.9088 - val_loss: 0.0982 - val_accuracy: 0.8904
#
# Epoch 00037: val_accuracy did not improve from 0.89726
# Epoch 38/100
# 10/10 [==============================] - 2s 218ms/step - loss: 0.0620 - accuracy: 0.9251 - val_loss: 0.1052 - val_accuracy: 0.8493
#
# Epoch 00038: val_accuracy did not improve from 0.89726
# Epoch 39/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0616 - accuracy: 0.9251 - val_loss: 0.0988 - val_accuracy: 0.8767
#
# Epoch 00039: val_accuracy did not improve from 0.89726
# Epoch 40/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0601 - accuracy: 0.9251 - val_loss: 0.0980 - val_accuracy: 0.8630
#
# Epoch 00040: val_accuracy did not improve from 0.89726
# Epoch 41/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0570 - accuracy: 0.9218 - val_loss: 0.0989 - val_accuracy: 0.8562
#
# Epoch 00041: val_accuracy did not improve from 0.89726
# Epoch 42/100
# 10/10 [==============================] - 2s 225ms/step - loss: 0.0574 - accuracy: 0.9186 - val_loss: 0.1080 - val_accuracy: 0.8493
#
# Epoch 00042: val_accuracy did not improve from 0.89726
# Epoch 43/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0586 - accuracy: 0.9349 - val_loss: 0.1196 - val_accuracy: 0.8425
#
# Epoch 00043: val_accuracy did not improve from 0.89726
# Epoch 44/100
# 10/10 [==============================] - 2s 220ms/step - loss: 0.0552 - accuracy: 0.9414 - val_loss: 0.1029 - val_accuracy: 0.8562
#
# Epoch 00044: val_accuracy did not improve from 0.89726
# Epoch 45/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0557 - accuracy: 0.9446 - val_loss: 0.1090 - val_accuracy: 0.8425
#
# Epoch 00045: val_accuracy did not improve from 0.89726
# Epoch 46/100
# 10/10 [==============================] - 2s 226ms/step - loss: 0.0536 - accuracy: 0.9446 - val_loss: 0.1036 - val_accuracy: 0.8699
#
# Epoch 00046: val_accuracy did not improve from 0.89726
# Epoch 47/100
# 10/10 [==============================] - 2s 220ms/step - loss: 0.0518 - accuracy: 0.9414 - val_loss: 0.0964 - val_accuracy: 0.8904
#
# Epoch 00047: val_accuracy did not improve from 0.89726
# Epoch 48/100
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0529 - accuracy: 0.9414 - val_loss: 0.0984 - val_accuracy: 0.8904
#
# Epoch 00048: val_accuracy did not improve from 0.89726
# Epoch 49/100
# 10/10 [==============================] - 2s 227ms/step - loss: 0.0511 - accuracy: 0.9316 - val_loss: 0.0973 - val_accuracy: 0.8767
#
# Epoch 00049: val_accuracy did not improve from 0.89726
# Epoch 50/100
# 10/10 [==============================] - 2s 222ms/step - loss: 0.0524 - accuracy: 0.9414 - val_loss: 0.1116 - val_accuracy: 0.8288
#
# Epoch 00050: val_accuracy did not improve from 0.89726
# Epoch 51/100
# 10/10 [==============================] - 2s 216ms/step - loss: 0.0501 - accuracy: 0.9349 - val_loss: 0.0966 - val_accuracy: 0.8836
#
# Epoch 00051: val_accuracy did not improve from 0.89726
# Epoch 52/100
# 10/10 [==============================] - 2s 216ms/step - loss: 0.0473 - accuracy: 0.9381 - val_loss: 0.1026 - val_accuracy: 0.8630
#
# Epoch 00052: val_accuracy did not improve from 0.89726
# Epoch 53/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0461 - accuracy: 0.9544 - val_loss: 0.0985 - val_accuracy: 0.8767
#
# Epoch 00053: val_accuracy did not improve from 0.89726
# Epoch 54/100
# 10/10 [==============================] - 2s 222ms/step - loss: 0.0483 - accuracy: 0.9511 - val_loss: 0.0988 - val_accuracy: 0.8836
#
# Epoch 00054: val_accuracy did not improve from 0.89726
# Epoch 55/100
# 10/10 [==============================] - 2s 216ms/step - loss: 0.0433 - accuracy: 0.9511 - val_loss: 0.0964 - val_accuracy: 0.8973
#
# Epoch 00055: val_accuracy did not improve from 0.89726
# Epoch 56/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0448 - accuracy: 0.9479 - val_loss: 0.0977 - val_accuracy: 0.8836
#
# Epoch 00056: val_accuracy did not improve from 0.89726
# Epoch 57/100
# 10/10 [==============================] - 2s 223ms/step - loss: 0.0450 - accuracy: 0.9381 - val_loss: 0.1045 - val_accuracy: 0.8699
#
# Epoch 00057: val_accuracy did not improve from 0.89726
# Epoch 58/100
# 10/10 [==============================] - 2s 219ms/step - loss: 0.0432 - accuracy: 0.9446 - val_loss: 0.1004 - val_accuracy: 0.8767
#
# Epoch 00058: val_accuracy did not improve from 0.89726
# Epoch 59/100
# 10/10 [==============================] - 2s 214ms/step - loss: 0.0459 - accuracy: 0.9446 - val_loss: 0.1057 - val_accuracy: 0.8904
#
# Epoch 00059: val_accuracy did not improve from 0.89726
# Epoch 60/100
# 10/10 [==============================] - 2s 216ms/step - loss: 0.0450 - accuracy: 0.9511 - val_loss: 0.1037 - val_accuracy: 0.8493
#
# Epoch 00060: val_accuracy did not improve from 0.89726
# Epoch 61/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0393 - accuracy: 0.9577 - val_loss: 0.1133 - val_accuracy: 0.8425
#
# Epoch 00061: val_accuracy did not improve from 0.89726
# Epoch 62/100
# 10/10 [==============================] - 2s 218ms/step - loss: 0.0405 - accuracy: 0.9479 - val_loss: 0.1028 - val_accuracy: 0.8562
#
# Epoch 00062: val_accuracy did not improve from 0.89726
# Epoch 63/100
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0366 - accuracy: 0.9577 - val_loss: 0.1019 - val_accuracy: 0.8767
#
# Epoch 00063: val_accuracy did not improve from 0.89726
# Epoch 64/100
# 10/10 [==============================] - 2s 222ms/step - loss: 0.0377 - accuracy: 0.9609 - val_loss: 0.1037 - val_accuracy: 0.8562
#
# Epoch 00064: val_accuracy did not improve from 0.89726
# Epoch 65/100
# 10/10 [==============================] - 2s 227ms/step - loss: 0.0351 - accuracy: 0.9577 - val_loss: 0.1145 - val_accuracy: 0.8562
#
# Epoch 00065: val_accuracy did not improve from 0.89726
# Epoch 66/100
# 10/10 [==============================] - 2s 225ms/step - loss: 0.0359 - accuracy: 0.9609 - val_loss: 0.1114 - val_accuracy: 0.8562
#
# Epoch 00066: val_accuracy did not improve from 0.89726
# Epoch 67/100
# 10/10 [==============================] - 2s 224ms/step - loss: 0.0349 - accuracy: 0.9674 - val_loss: 0.1250 - val_accuracy: 0.8288
#
# Epoch 00067: val_accuracy did not improve from 0.89726
# Epoch 68/100
# 10/10 [==============================] - 2s 223ms/step - loss: 0.0386 - accuracy: 0.9511 - val_loss: 0.1095 - val_accuracy: 0.8699
#
# Epoch 00068: val_accuracy did not improve from 0.89726
# Epoch 69/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0348 - accuracy: 0.9642 - val_loss: 0.1073 - val_accuracy: 0.8699
#
# Epoch 00069: val_accuracy did not improve from 0.89726
# Epoch 70/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0344 - accuracy: 0.9609 - val_loss: 0.1021 - val_accuracy: 0.8973
#
# Epoch 00070: val_accuracy did not improve from 0.89726
# Epoch 71/100
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0301 - accuracy: 0.9707 - val_loss: 0.1025 - val_accuracy: 0.8836
#
# Epoch 00071: val_accuracy did not improve from 0.89726
# Epoch 72/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0281 - accuracy: 0.9707 - val_loss: 0.1025 - val_accuracy: 0.8699
#
# Epoch 00072: val_accuracy did not improve from 0.89726
# Epoch 73/100
# 10/10 [==============================] - 2s 221ms/step - loss: 0.0286 - accuracy: 0.9707 - val_loss: 0.1120 - val_accuracy: 0.8630
#
# Epoch 00073: val_accuracy did not improve from 0.89726
# Epoch 74/100
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0248 - accuracy: 0.9837 - val_loss: 0.1115 - val_accuracy: 0.8630
#
# Epoch 00074: val_accuracy did not improve from 0.89726
# Epoch 75/100
# 10/10 [==============================] - 3s 259ms/step - loss: 0.0298 - accuracy: 0.9656 - val_loss: 0.1052 - val_accuracy: 0.8767
#
# Epoch 00075: val_accuracy did not improve from 0.89726
# Epoch 76/100
# 10/10 [==============================] - 3s 304ms/step - loss: 0.0280 - accuracy: 0.9674 - val_loss: 0.1071 - val_accuracy: 0.8699
#
# Epoch 00076: val_accuracy did not improve from 0.89726
# Epoch 77/100
# 10/10 [==============================] - 3s 275ms/step - loss: 0.0288 - accuracy: 0.9739 - val_loss: 0.1072 - val_accuracy: 0.8699
#
# Epoch 00077: val_accuracy did not improve from 0.89726
# Epoch 78/100
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0307 - accuracy: 0.9805 - val_loss: 0.1110 - val_accuracy: 0.8699
#
# Epoch 00078: val_accuracy did not improve from 0.89726
# Epoch 79/100
# 10/10 [==============================] - 3s 266ms/step - loss: 0.0285 - accuracy: 0.9739 - val_loss: 0.1115 - val_accuracy: 0.8836
#
# Epoch 00079: val_accuracy did not improve from 0.89726
# Epoch 80/100
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0253 - accuracy: 0.9805 - val_loss: 0.1011 - val_accuracy: 0.8836
#
# Epoch 00080: val_accuracy did not improve from 0.89726
# Epoch 81/100
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0300 - accuracy: 0.9739 - val_loss: 0.1063 - val_accuracy: 0.8562
#
# Epoch 00081: val_accuracy did not improve from 0.89726
# Epoch 82/100
# 10/10 [==============================] - 7s 766ms/step - loss: 0.0287 - accuracy: 0.9642 - val_loss: 0.1027 - val_accuracy: 0.8904
#
# Epoch 00082: val_accuracy did not improve from 0.89726
# Epoch 83/100
# 10/10 [==============================] - 7s 723ms/step - loss: 0.0222 - accuracy: 0.9772 - val_loss: 0.1040 - val_accuracy: 0.8904
#
# Epoch 00083: val_accuracy did not improve from 0.89726
# Epoch 84/100
# 10/10 [==============================] - 7s 751ms/step - loss: 0.0229 - accuracy: 0.9750 - val_loss: 0.1059 - val_accuracy: 0.8904
#
# Epoch 00084: val_accuracy did not improve from 0.89726
# Epoch 85/100
# 10/10 [==============================] - 7s 721ms/step - loss: 0.0207 - accuracy: 0.9870 - val_loss: 0.1035 - val_accuracy: 0.8904
#
# Epoch 00085: val_accuracy did not improve from 0.89726
# Epoch 86/100
# 10/10 [==============================] - 7s 747ms/step - loss: 0.0212 - accuracy: 0.9805 - val_loss: 0.1059 - val_accuracy: 0.8836
#
# Epoch 00086: val_accuracy did not improve from 0.89726
# Epoch 87/100
# 10/10 [==============================] - 7s 730ms/step - loss: 0.0197 - accuracy: 0.9870 - val_loss: 0.1085 - val_accuracy: 0.8836
#
# Epoch 00087: val_accuracy did not improve from 0.89726
# Epoch 88/100
# 10/10 [==============================] - 7s 716ms/step - loss: 0.0195 - accuracy: 0.9837 - val_loss: 0.1059 - val_accuracy: 0.8767
#
# Epoch 00088: val_accuracy did not improve from 0.89726
# Epoch 89/100
# 10/10 [==============================] - 7s 751ms/step - loss: 0.0193 - accuracy: 0.9812 - val_loss: 0.1118 - val_accuracy: 0.8630
#
# Epoch 00089: val_accuracy did not improve from 0.89726
# Epoch 90/100
# 10/10 [==============================] - 7s 720ms/step - loss: 0.0219 - accuracy: 0.9837 - val_loss: 0.1098 - val_accuracy: 0.8493
#
# Epoch 00090: val_accuracy did not improve from 0.89726
# Epoch 91/100
# 10/10 [==============================] - 7s 720ms/step - loss: 0.0178 - accuracy: 0.9902 - val_loss: 0.1032 - val_accuracy: 0.8836
#
# Epoch 00091: val_accuracy did not improve from 0.89726
# Epoch 92/100
# 10/10 [==============================] - 7s 684ms/step - loss: 0.0207 - accuracy: 0.9902 - val_loss: 0.1103 - val_accuracy: 0.8699
#
# Epoch 00092: val_accuracy did not improve from 0.89726
# Epoch 93/100
# 10/10 [==============================] - 7s 694ms/step - loss: 0.0225 - accuracy: 0.9837 - val_loss: 0.1008 - val_accuracy: 0.8973
#
# Epoch 00093: val_accuracy did not improve from 0.89726
# Epoch 94/100
# 10/10 [==============================] - 7s 689ms/step - loss: 0.0173 - accuracy: 0.9902 - val_loss: 0.1063 - val_accuracy: 0.8973
#
# Epoch 00094: val_accuracy did not improve from 0.89726
# Epoch 95/100
# 10/10 [==============================] - 7s 690ms/step - loss: 0.0152 - accuracy: 0.9967 - val_loss: 0.1053 - val_accuracy: 0.8767
#
# Epoch 00095: val_accuracy did not improve from 0.89726
# Epoch 96/100
# 10/10 [==============================] - 7s 694ms/step - loss: 0.0137 - accuracy: 0.9902 - val_loss: 0.1070 - val_accuracy: 0.8767
#
# Epoch 00096: val_accuracy did not improve from 0.89726
# Epoch 97/100
# 10/10 [==============================] - 7s 716ms/step - loss: 0.0164 - accuracy: 0.9902 - val_loss: 0.1060 - val_accuracy: 0.8767
#
# Epoch 00097: val_accuracy did not improve from 0.89726
# Epoch 98/100
# 10/10 [==============================] - 7s 690ms/step - loss: 0.0144 - accuracy: 0.9967 - val_loss: 0.1058 - val_accuracy: 0.8904
#
# Epoch 00098: val_accuracy did not improve from 0.89726
# Epoch 99/100
# 10/10 [==============================] - 7s 690ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.1051 - val_accuracy: 0.8836
#
# Epoch 00099: val_accuracy did not improve from 0.89726
# Epoch 100/100
# 10/10 [==============================] - 7s 689ms/step - loss: 0.0117 - accuracy: 0.9935 - val_loss: 0.1039 - val_accuracy: 0.8836
#
# Epoch 00100: val_accuracy did not improve from 0.89726
# Best Validation Accuracy:0.8972602486610413
# *******Model Performance*************
# Test acc: 0.8972602739726028
# Precision:0.883495145631068
# recall:0.9680851063829787
# f1:0.9238578680203046
# AUC:0.8686579378068738
# Sensitivity:0.9680851063829787
# specificity:0.7692307692307693

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=64
WIDTH=64
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [7],filters=[128],strides=[2])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(32, 64, 64, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 29, 29, 128)         18944
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 12, 12, 128)         802944
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 2304, 8)             0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 2304, 8)             0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               589824
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 1,411,712
# Trainable params: 1,411,712
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 3s 227ms/step - loss: 0.5199 - accuracy: 0.4169 - val_loss: 0.3196 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/100
# 10/10 [==============================] - 1s 147ms/step - loss: 0.3018 - accuracy: 0.6482 - val_loss: 0.2704 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.2586 - accuracy: 0.6515 - val_loss: 0.2636 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/100
# 10/10 [==============================] - 1s 147ms/step - loss: 0.2394 - accuracy: 0.6482 - val_loss: 0.2430 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.2283 - accuracy: 0.6482 - val_loss: 0.2346 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.2188 - accuracy: 0.6482 - val_loss: 0.2261 - val_accuracy: 0.6438
#
# Epoch 00006: val_accuracy did not improve from 0.64384
# Epoch 7/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.2122 - accuracy: 0.6319 - val_loss: 0.2160 - val_accuracy: 0.6233
#
# Epoch 00007: val_accuracy did not improve from 0.64384
# Epoch 8/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.1990 - accuracy: 0.6612 - val_loss: 0.2071 - val_accuracy: 0.6233
#
# Epoch 00008: val_accuracy did not improve from 0.64384
# Epoch 9/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.2026 - accuracy: 0.6319 - val_loss: 0.1960 - val_accuracy: 0.6575
#
# Epoch 00009: val_accuracy improved from 0.64384 to 0.65753, saving model to ./result\weights.h5
# Epoch 10/100
# 10/10 [==============================] - 1s 150ms/step - loss: 0.1888 - accuracy: 0.6844 - val_loss: 0.2012 - val_accuracy: 0.6438
#
# Epoch 00010: val_accuracy did not improve from 0.65753
# Epoch 11/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.1882 - accuracy: 0.6547 - val_loss: 0.1809 - val_accuracy: 0.6644
#
# Epoch 00011: val_accuracy improved from 0.65753 to 0.66438, saving model to ./result\weights.h5
# Epoch 12/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.1773 - accuracy: 0.6775 - val_loss: 0.1793 - val_accuracy: 0.6644
#
# Epoch 00012: val_accuracy did not improve from 0.66438
# Epoch 13/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.1672 - accuracy: 0.6873 - val_loss: 0.1690 - val_accuracy: 0.6781
#
# Epoch 00013: val_accuracy improved from 0.66438 to 0.67808, saving model to ./result\weights.h5
# Epoch 14/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.1630 - accuracy: 0.6971 - val_loss: 0.1654 - val_accuracy: 0.7055
#
# Epoch 00014: val_accuracy improved from 0.67808 to 0.70548, saving model to ./result\weights.h5
# Epoch 15/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.1675 - accuracy: 0.7101 - val_loss: 0.1567 - val_accuracy: 0.7260
#
# Epoch 00015: val_accuracy improved from 0.70548 to 0.72603, saving model to ./result\weights.h5
# Epoch 16/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.1766 - accuracy: 0.6938 - val_loss: 0.1762 - val_accuracy: 0.6644
#
# Epoch 00016: val_accuracy did not improve from 0.72603
# Epoch 17/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.1517 - accuracy: 0.7394 - val_loss: 0.1511 - val_accuracy: 0.7534
#
# Epoch 00017: val_accuracy improved from 0.72603 to 0.75342, saving model to ./result\weights.h5
# Epoch 18/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.1430 - accuracy: 0.7394 - val_loss: 0.1463 - val_accuracy: 0.7397
#
# Epoch 00018: val_accuracy did not improve from 0.75342
# Epoch 19/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.1350 - accuracy: 0.7655 - val_loss: 0.1432 - val_accuracy: 0.7466
#
# Epoch 00019: val_accuracy did not improve from 0.75342
# Epoch 20/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.1377 - accuracy: 0.7785 - val_loss: 0.1344 - val_accuracy: 0.7603
#
# Epoch 00020: val_accuracy improved from 0.75342 to 0.76027, saving model to ./result\weights.h5
# Epoch 21/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.1325 - accuracy: 0.7752 - val_loss: 0.1310 - val_accuracy: 0.7808
#
# Epoch 00021: val_accuracy improved from 0.76027 to 0.78082, saving model to ./result\weights.h5
# Epoch 22/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.1214 - accuracy: 0.7844 - val_loss: 0.1245 - val_accuracy: 0.7808
#
# Epoch 00022: val_accuracy did not improve from 0.78082
# Epoch 23/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.1234 - accuracy: 0.7980 - val_loss: 0.1234 - val_accuracy: 0.8014
#
# Epoch 00023: val_accuracy improved from 0.78082 to 0.80137, saving model to ./result\weights.h5
# Epoch 24/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.1199 - accuracy: 0.7915 - val_loss: 0.1197 - val_accuracy: 0.8082
#
# Epoch 00024: val_accuracy improved from 0.80137 to 0.80822, saving model to ./result\weights.h5
# Epoch 25/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.1154 - accuracy: 0.8111 - val_loss: 0.1234 - val_accuracy: 0.7671
#
# Epoch 00025: val_accuracy did not improve from 0.80822
# Epoch 26/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.1135 - accuracy: 0.7883 - val_loss: 0.1132 - val_accuracy: 0.8151
#
# Epoch 00026: val_accuracy improved from 0.80822 to 0.81507, saving model to ./result\weights.h5
# Epoch 27/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.1065 - accuracy: 0.8208 - val_loss: 0.1081 - val_accuracy: 0.8425
#
# Epoch 00027: val_accuracy improved from 0.81507 to 0.84247, saving model to ./result\weights.h5
# Epoch 28/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.1078 - accuracy: 0.8125 - val_loss: 0.1092 - val_accuracy: 0.8493
#
# Epoch 00028: val_accuracy improved from 0.84247 to 0.84932, saving model to ./result\weights.h5
# Epoch 29/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.1137 - accuracy: 0.8274 - val_loss: 0.1273 - val_accuracy: 0.7808
#
# Epoch 00029: val_accuracy did not improve from 0.84932
# Epoch 30/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.1059 - accuracy: 0.8371 - val_loss: 0.1115 - val_accuracy: 0.8219
#
# Epoch 00030: val_accuracy did not improve from 0.84932
# Epoch 31/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.1017 - accuracy: 0.8469 - val_loss: 0.1035 - val_accuracy: 0.8630
#
# Epoch 00031: val_accuracy improved from 0.84932 to 0.86301, saving model to ./result\weights.h5
# Epoch 32/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0986 - accuracy: 0.8436 - val_loss: 0.1005 - val_accuracy: 0.8630
#
# Epoch 00032: val_accuracy did not improve from 0.86301
# Epoch 33/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0930 - accuracy: 0.8469 - val_loss: 0.1005 - val_accuracy: 0.8767
#
# Epoch 00033: val_accuracy improved from 0.86301 to 0.87671, saving model to ./result\weights.h5
# Epoch 34/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0877 - accuracy: 0.8697 - val_loss: 0.0992 - val_accuracy: 0.8904
#
# Epoch 00034: val_accuracy improved from 0.87671 to 0.89041, saving model to ./result\weights.h5
# Epoch 35/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0902 - accuracy: 0.8632 - val_loss: 0.0983 - val_accuracy: 0.8973
#
# Epoch 00035: val_accuracy improved from 0.89041 to 0.89726, saving model to ./result\weights.h5
# Epoch 36/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0830 - accuracy: 0.8827 - val_loss: 0.1002 - val_accuracy: 0.8493
#
# Epoch 00036: val_accuracy did not improve from 0.89726
# Epoch 37/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0970 - accuracy: 0.8274 - val_loss: 0.0942 - val_accuracy: 0.8699
#
# Epoch 00037: val_accuracy did not improve from 0.89726
# Epoch 38/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0849 - accuracy: 0.8893 - val_loss: 0.0932 - val_accuracy: 0.8904
#
# Epoch 00038: val_accuracy did not improve from 0.89726
# Epoch 39/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0811 - accuracy: 0.8827 - val_loss: 0.1015 - val_accuracy: 0.8904
#
# Epoch 00039: val_accuracy did not improve from 0.89726
# Epoch 40/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0904 - accuracy: 0.8436 - val_loss: 0.0949 - val_accuracy: 0.8904
#
# Epoch 00040: val_accuracy did not improve from 0.89726
# Epoch 41/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0879 - accuracy: 0.8632 - val_loss: 0.0932 - val_accuracy: 0.8767
#
# Epoch 00041: val_accuracy did not improve from 0.89726
# Epoch 42/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0826 - accuracy: 0.8762 - val_loss: 0.0903 - val_accuracy: 0.8836
#
# Epoch 00042: val_accuracy did not improve from 0.89726
# Epoch 43/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0745 - accuracy: 0.8925 - val_loss: 0.0984 - val_accuracy: 0.8904
#
# Epoch 00043: val_accuracy did not improve from 0.89726
# Epoch 44/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0799 - accuracy: 0.8795 - val_loss: 0.0886 - val_accuracy: 0.8973
#
# Epoch 00044: val_accuracy did not improve from 0.89726
# Epoch 45/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0800 - accuracy: 0.8730 - val_loss: 0.0883 - val_accuracy: 0.8973
#
# Epoch 00045: val_accuracy did not improve from 0.89726
# Epoch 46/100
# 10/10 [==============================] - 2s 165ms/step - loss: 0.0786 - accuracy: 0.8795 - val_loss: 0.0876 - val_accuracy: 0.8836
#
# Epoch 00046: val_accuracy did not improve from 0.89726
# Epoch 47/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0768 - accuracy: 0.8860 - val_loss: 0.0855 - val_accuracy: 0.8973
#
# Epoch 00047: val_accuracy did not improve from 0.89726
# Epoch 48/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0804 - accuracy: 0.8795 - val_loss: 0.0946 - val_accuracy: 0.8904
#
# Epoch 00048: val_accuracy did not improve from 0.89726
# Epoch 49/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0761 - accuracy: 0.8860 - val_loss: 0.0896 - val_accuracy: 0.8904
#
# Epoch 00049: val_accuracy did not improve from 0.89726
# Epoch 50/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0750 - accuracy: 0.8893 - val_loss: 0.1036 - val_accuracy: 0.8562
#
# Epoch 00050: val_accuracy did not improve from 0.89726
# Epoch 51/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0812 - accuracy: 0.8893 - val_loss: 0.0941 - val_accuracy: 0.8630
#
# Epoch 00051: val_accuracy did not improve from 0.89726
# Epoch 52/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0768 - accuracy: 0.8860 - val_loss: 0.0903 - val_accuracy: 0.8904
#
# Epoch 00052: val_accuracy did not improve from 0.89726
# Epoch 53/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0732 - accuracy: 0.9055 - val_loss: 0.0875 - val_accuracy: 0.9041
#
# Epoch 00053: val_accuracy improved from 0.89726 to 0.90411, saving model to ./result\weights.h5
# Epoch 54/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0726 - accuracy: 0.8925 - val_loss: 0.0902 - val_accuracy: 0.8904
#
# Epoch 00054: val_accuracy did not improve from 0.90411
# Epoch 55/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0673 - accuracy: 0.9153 - val_loss: 0.0894 - val_accuracy: 0.8904
#
# Epoch 00055: val_accuracy did not improve from 0.90411
# Epoch 56/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0690 - accuracy: 0.8990 - val_loss: 0.0853 - val_accuracy: 0.9041
#
# Epoch 00056: val_accuracy did not improve from 0.90411
# Epoch 57/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0685 - accuracy: 0.9055 - val_loss: 0.0849 - val_accuracy: 0.9110
#
# Epoch 00057: val_accuracy improved from 0.90411 to 0.91096, saving model to ./result\weights.h5
# Epoch 58/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0661 - accuracy: 0.8990 - val_loss: 0.0956 - val_accuracy: 0.8836
#
# Epoch 00058: val_accuracy did not improve from 0.91096
# Epoch 59/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0720 - accuracy: 0.9023 - val_loss: 0.0870 - val_accuracy: 0.8973
#
# Epoch 00059: val_accuracy did not improve from 0.91096
# Epoch 60/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0698 - accuracy: 0.8958 - val_loss: 0.0815 - val_accuracy: 0.8973
#
# Epoch 00060: val_accuracy did not improve from 0.91096
# Epoch 61/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0603 - accuracy: 0.9153 - val_loss: 0.0900 - val_accuracy: 0.8973
#
# Epoch 00061: val_accuracy did not improve from 0.91096
# Epoch 62/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0602 - accuracy: 0.9055 - val_loss: 0.0845 - val_accuracy: 0.9041
#
# Epoch 00062: val_accuracy did not improve from 0.91096
# Epoch 63/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0623 - accuracy: 0.9088 - val_loss: 0.0831 - val_accuracy: 0.9041
#
# Epoch 00063: val_accuracy did not improve from 0.91096
# Epoch 64/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0642 - accuracy: 0.9023 - val_loss: 0.1070 - val_accuracy: 0.8288
#
# Epoch 00064: val_accuracy did not improve from 0.91096
# Epoch 65/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0656 - accuracy: 0.8990 - val_loss: 0.0865 - val_accuracy: 0.8973
#
# Epoch 00065: val_accuracy did not improve from 0.91096
# Epoch 66/100
# 10/10 [==============================] - 2s 152ms/step - loss: 0.0678 - accuracy: 0.9121 - val_loss: 0.0914 - val_accuracy: 0.8630
#
# Epoch 00066: val_accuracy did not improve from 0.91096
# Epoch 67/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0669 - accuracy: 0.8958 - val_loss: 0.0899 - val_accuracy: 0.8904
#
# Epoch 00067: val_accuracy did not improve from 0.91096
# Epoch 68/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0568 - accuracy: 0.9153 - val_loss: 0.0914 - val_accuracy: 0.8904
#
# Epoch 00068: val_accuracy did not improve from 0.91096
# Epoch 69/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0583 - accuracy: 0.9251 - val_loss: 0.0904 - val_accuracy: 0.8699
#
# Epoch 00069: val_accuracy did not improve from 0.91096
# Epoch 70/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0616 - accuracy: 0.9023 - val_loss: 0.0843 - val_accuracy: 0.8973
#
# Epoch 00070: val_accuracy did not improve from 0.91096
# Epoch 71/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0565 - accuracy: 0.9218 - val_loss: 0.0862 - val_accuracy: 0.8973
#
# Epoch 00071: val_accuracy did not improve from 0.91096
# Epoch 72/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0542 - accuracy: 0.9186 - val_loss: 0.0865 - val_accuracy: 0.8973
#
# Epoch 00072: val_accuracy did not improve from 0.91096
# Epoch 73/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0577 - accuracy: 0.9251 - val_loss: 0.1118 - val_accuracy: 0.8562
#
# Epoch 00073: val_accuracy did not improve from 0.91096
# Epoch 74/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0554 - accuracy: 0.9349 - val_loss: 0.0849 - val_accuracy: 0.8904
#
# Epoch 00074: val_accuracy did not improve from 0.91096
# Epoch 75/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0581 - accuracy: 0.9219 - val_loss: 0.0864 - val_accuracy: 0.8973
#
# Epoch 00075: val_accuracy did not improve from 0.91096
# Epoch 76/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0568 - accuracy: 0.9055 - val_loss: 0.0900 - val_accuracy: 0.8904
#
# Epoch 00076: val_accuracy did not improve from 0.91096
# Epoch 77/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0575 - accuracy: 0.9153 - val_loss: 0.0868 - val_accuracy: 0.8904
#
# Epoch 00077: val_accuracy did not improve from 0.91096
# Epoch 78/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0553 - accuracy: 0.9153 - val_loss: 0.0881 - val_accuracy: 0.8904
#
# Epoch 00078: val_accuracy did not improve from 0.91096
# Epoch 79/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0521 - accuracy: 0.9283 - val_loss: 0.0959 - val_accuracy: 0.8699
#
# Epoch 00079: val_accuracy did not improve from 0.91096
# Epoch 80/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0501 - accuracy: 0.9414 - val_loss: 0.0860 - val_accuracy: 0.8973
#
# Epoch 00080: val_accuracy did not improve from 0.91096
# Epoch 81/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0541 - accuracy: 0.9381 - val_loss: 0.0867 - val_accuracy: 0.8767
#
# Epoch 00081: val_accuracy did not improve from 0.91096
# Epoch 82/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0548 - accuracy: 0.9218 - val_loss: 0.0970 - val_accuracy: 0.8767
#
# Epoch 00082: val_accuracy did not improve from 0.91096
# Epoch 83/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0508 - accuracy: 0.9283 - val_loss: 0.0914 - val_accuracy: 0.8699
#
# Epoch 00083: val_accuracy did not improve from 0.91096
# Epoch 84/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0538 - accuracy: 0.9281 - val_loss: 0.0951 - val_accuracy: 0.8630
#
# Epoch 00084: val_accuracy did not improve from 0.91096
# Epoch 85/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0504 - accuracy: 0.9381 - val_loss: 0.0953 - val_accuracy: 0.8767
#
# Epoch 00085: val_accuracy did not improve from 0.91096
# Epoch 86/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0493 - accuracy: 0.9316 - val_loss: 0.0918 - val_accuracy: 0.8767
#
# Epoch 00086: val_accuracy did not improve from 0.91096
# Epoch 87/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0489 - accuracy: 0.9381 - val_loss: 0.0916 - val_accuracy: 0.8836
#
# Epoch 00087: val_accuracy did not improve from 0.91096
# Epoch 88/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0476 - accuracy: 0.9349 - val_loss: 0.0880 - val_accuracy: 0.8767
#
# Epoch 00088: val_accuracy did not improve from 0.91096
# Epoch 89/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0469 - accuracy: 0.9312 - val_loss: 0.0897 - val_accuracy: 0.8904
#
# Epoch 00089: val_accuracy did not improve from 0.91096
# Epoch 90/100
# 10/10 [==============================] - 2s 152ms/step - loss: 0.0463 - accuracy: 0.9414 - val_loss: 0.0916 - val_accuracy: 0.8836
#
# Epoch 00090: val_accuracy did not improve from 0.91096
# Epoch 91/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0446 - accuracy: 0.9479 - val_loss: 0.0890 - val_accuracy: 0.8904
#
# Epoch 00091: val_accuracy did not improve from 0.91096
# Epoch 92/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.0489 - accuracy: 0.9349 - val_loss: 0.0862 - val_accuracy: 0.8904
#
# Epoch 00092: val_accuracy did not improve from 0.91096
# Epoch 93/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0486 - accuracy: 0.9381 - val_loss: 0.0878 - val_accuracy: 0.8767
#
# Epoch 00093: val_accuracy did not improve from 0.91096
# Epoch 94/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.0442 - accuracy: 0.9414 - val_loss: 0.0930 - val_accuracy: 0.8836
#
# Epoch 00094: val_accuracy did not improve from 0.91096
# Epoch 95/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0469 - accuracy: 0.9544 - val_loss: 0.0885 - val_accuracy: 0.8836
#
# Epoch 00095: val_accuracy did not improve from 0.91096
# Epoch 96/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0440 - accuracy: 0.9414 - val_loss: 0.0928 - val_accuracy: 0.8836
#
# Epoch 00096: val_accuracy did not improve from 0.91096
# Epoch 97/100
# 10/10 [==============================] - 2s 181ms/step - loss: 0.0446 - accuracy: 0.9446 - val_loss: 0.0920 - val_accuracy: 0.8904
#
# Epoch 00097: val_accuracy did not improve from 0.91096
# Epoch 98/100
# 10/10 [==============================] - 2s 166ms/step - loss: 0.0433 - accuracy: 0.9479 - val_loss: 0.0892 - val_accuracy: 0.8767
#
# Epoch 00098: val_accuracy did not improve from 0.91096
# Epoch 99/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0435 - accuracy: 0.9479 - val_loss: 0.0854 - val_accuracy: 0.9041
#
# Epoch 00099: val_accuracy did not improve from 0.91096
# Epoch 100/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0395 - accuracy: 0.9577 - val_loss: 0.0910 - val_accuracy: 0.8904
#
# Epoch 00100: val_accuracy did not improve from 0.91096
# Best Validation Accuracy:0.9109588861465454
# *******Model Performance*************
# Test acc: 0.910958904109589
# Precision:0.8932038834951457
# recall:0.9787234042553191
# f1:0.934010152284264
# AUC:0.8835924713584288
# Sensitivity:0.9787234042553191
# specificity:0.7884615384615384

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=64
WIDTH=64
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [7,9],filters=[128,256],strides=[2,2])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(32, 64, 64, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 29, 29, 128)         18944
# _________________________________________________________________
# conv1 (Conv2D)               (32, 11, 11, 256)         2654464
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 2, 2, 256)           5308672
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 128, 8)              0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 128, 8)              0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               32768
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 8,014,848
# Trainable params: 8,014,848
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 2s 175ms/step - loss: 0.5287 - accuracy: 0.6352 - val_loss: 0.2018 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2090 - accuracy: 0.6482 - val_loss: 0.2070 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2005 - accuracy: 0.6515 - val_loss: 0.1997 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.1988 - accuracy: 0.6482 - val_loss: 0.1973 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1963 - accuracy: 0.6482 - val_loss: 0.1970 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1960 - accuracy: 0.6482 - val_loss: 0.1968 - val_accuracy: 0.6438
#
# Epoch 00006: val_accuracy did not improve from 0.64384
# Epoch 7/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.1956 - accuracy: 0.6482 - val_loss: 0.1964 - val_accuracy: 0.6438
#
# Epoch 00007: val_accuracy did not improve from 0.64384
# Epoch 8/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.1953 - accuracy: 0.6482 - val_loss: 0.1960 - val_accuracy: 0.6438
#
# Epoch 00008: val_accuracy did not improve from 0.64384
# Epoch 9/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.1962 - accuracy: 0.6417 - val_loss: 0.1951 - val_accuracy: 0.6438
#
# Epoch 00009: val_accuracy did not improve from 0.64384
# Epoch 10/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.1927 - accuracy: 0.6500 - val_loss: 0.1934 - val_accuracy: 0.6438
#
# Epoch 00010: val_accuracy did not improve from 0.64384
# Epoch 11/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1918 - accuracy: 0.6450 - val_loss: 0.1904 - val_accuracy: 0.6438
#
# Epoch 00011: val_accuracy did not improve from 0.64384
# Epoch 12/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1853 - accuracy: 0.6450 - val_loss: 0.1859 - val_accuracy: 0.6438
#
# Epoch 00012: val_accuracy did not improve from 0.64384
# Epoch 13/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1733 - accuracy: 0.6743 - val_loss: 0.1792 - val_accuracy: 0.6644
#
# Epoch 00013: val_accuracy improved from 0.64384 to 0.66438, saving model to ./result\weights.h5
# Epoch 14/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.1706 - accuracy: 0.7003 - val_loss: 0.1738 - val_accuracy: 0.6849
#
# Epoch 00014: val_accuracy improved from 0.66438 to 0.68493, saving model to ./result\weights.h5
# Epoch 15/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.1678 - accuracy: 0.7036 - val_loss: 0.1740 - val_accuracy: 0.6781
#
# Epoch 00015: val_accuracy did not improve from 0.68493
# Epoch 16/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.1623 - accuracy: 0.6906 - val_loss: 0.1599 - val_accuracy: 0.7055
#
# Epoch 00016: val_accuracy improved from 0.68493 to 0.70548, saving model to ./result\weights.h5
# Epoch 17/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1436 - accuracy: 0.7329 - val_loss: 0.1521 - val_accuracy: 0.7329
#
# Epoch 00017: val_accuracy improved from 0.70548 to 0.73288, saving model to ./result\weights.h5
# Epoch 18/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.1394 - accuracy: 0.7622 - val_loss: 0.1431 - val_accuracy: 0.7397
#
# Epoch 00018: val_accuracy improved from 0.73288 to 0.73973, saving model to ./result\weights.h5
# Epoch 19/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.1252 - accuracy: 0.7915 - val_loss: 0.1265 - val_accuracy: 0.8356
#
# Epoch 00019: val_accuracy improved from 0.73973 to 0.83562, saving model to ./result\weights.h5
# Epoch 20/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1120 - accuracy: 0.8176 - val_loss: 0.1144 - val_accuracy: 0.8288
#
# Epoch 00020: val_accuracy did not improve from 0.83562
# Epoch 21/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.1009 - accuracy: 0.8404 - val_loss: 0.1054 - val_accuracy: 0.8425
#
# Epoch 00021: val_accuracy improved from 0.83562 to 0.84247, saving model to ./result\weights.h5
# Epoch 22/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0917 - accuracy: 0.8719 - val_loss: 0.1032 - val_accuracy: 0.8562
#
# Epoch 00022: val_accuracy improved from 0.84247 to 0.85616, saving model to ./result\weights.h5
# Epoch 23/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0916 - accuracy: 0.8534 - val_loss: 0.0992 - val_accuracy: 0.8493
#
# Epoch 00023: val_accuracy did not improve from 0.85616
# Epoch 24/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0909 - accuracy: 0.8534 - val_loss: 0.1013 - val_accuracy: 0.8699
#
# Epoch 00024: val_accuracy improved from 0.85616 to 0.86986, saving model to ./result\weights.h5
# Epoch 25/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.0863 - accuracy: 0.8730 - val_loss: 0.0994 - val_accuracy: 0.8630
#
# Epoch 00025: val_accuracy did not improve from 0.86986
# Epoch 26/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.0825 - accuracy: 0.8599 - val_loss: 0.1052 - val_accuracy: 0.8493
#
# Epoch 00026: val_accuracy did not improve from 0.86986
# Epoch 27/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0775 - accuracy: 0.8827 - val_loss: 0.1007 - val_accuracy: 0.8562
#
# Epoch 00027: val_accuracy did not improve from 0.86986
# Epoch 28/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.0852 - accuracy: 0.8438 - val_loss: 0.0997 - val_accuracy: 0.8562
#
# Epoch 00028: val_accuracy did not improve from 0.86986
# Epoch 29/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.0773 - accuracy: 0.8795 - val_loss: 0.0990 - val_accuracy: 0.8630
#
# Epoch 00029: val_accuracy did not improve from 0.86986
# Epoch 30/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0810 - accuracy: 0.8827 - val_loss: 0.0957 - val_accuracy: 0.8630
#
# Epoch 00030: val_accuracy did not improve from 0.86986
# Epoch 31/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0751 - accuracy: 0.9023 - val_loss: 0.0981 - val_accuracy: 0.8493
#
# Epoch 00031: val_accuracy did not improve from 0.86986
# Epoch 32/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.0766 - accuracy: 0.8893 - val_loss: 0.0915 - val_accuracy: 0.8630
#
# Epoch 00032: val_accuracy did not improve from 0.86986
# Epoch 33/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0709 - accuracy: 0.8860 - val_loss: 0.1002 - val_accuracy: 0.8425
#
# Epoch 00033: val_accuracy did not improve from 0.86986
# Epoch 34/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.0699 - accuracy: 0.9088 - val_loss: 0.0916 - val_accuracy: 0.8699
#
# Epoch 00034: val_accuracy did not improve from 0.86986
# Epoch 35/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.0681 - accuracy: 0.9055 - val_loss: 0.0948 - val_accuracy: 0.8836
#
# Epoch 00035: val_accuracy improved from 0.86986 to 0.88356, saving model to ./result\weights.h5
# Epoch 36/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0651 - accuracy: 0.9153 - val_loss: 0.0928 - val_accuracy: 0.8699
#
# Epoch 00036: val_accuracy did not improve from 0.88356
# Epoch 37/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0705 - accuracy: 0.8827 - val_loss: 0.0933 - val_accuracy: 0.8767
#
# Epoch 00037: val_accuracy did not improve from 0.88356
# Epoch 38/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0670 - accuracy: 0.8990 - val_loss: 0.0911 - val_accuracy: 0.8699
#
# Epoch 00038: val_accuracy did not improve from 0.88356
# Epoch 39/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0629 - accuracy: 0.9153 - val_loss: 0.0915 - val_accuracy: 0.8767
#
# Epoch 00039: val_accuracy did not improve from 0.88356
# Epoch 40/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0624 - accuracy: 0.9153 - val_loss: 0.0907 - val_accuracy: 0.8699
#
# Epoch 00040: val_accuracy did not improve from 0.88356
# Epoch 41/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.0637 - accuracy: 0.9055 - val_loss: 0.0910 - val_accuracy: 0.8699
#
# Epoch 00041: val_accuracy did not improve from 0.88356
# Epoch 42/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.0633 - accuracy: 0.9023 - val_loss: 0.0889 - val_accuracy: 0.8767
#
# Epoch 00042: val_accuracy did not improve from 0.88356
# Epoch 43/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0568 - accuracy: 0.9153 - val_loss: 0.0939 - val_accuracy: 0.8630
#
# Epoch 00043: val_accuracy did not improve from 0.88356
# Epoch 44/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0589 - accuracy: 0.9055 - val_loss: 0.0883 - val_accuracy: 0.8630
#
# Epoch 00044: val_accuracy did not improve from 0.88356
# Epoch 45/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0591 - accuracy: 0.9088 - val_loss: 0.0944 - val_accuracy: 0.8630
#
# Epoch 00045: val_accuracy did not improve from 0.88356
# Epoch 46/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0550 - accuracy: 0.9218 - val_loss: 0.0861 - val_accuracy: 0.8699
#
# Epoch 00046: val_accuracy did not improve from 0.88356
# Epoch 47/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0556 - accuracy: 0.9121 - val_loss: 0.0863 - val_accuracy: 0.8904
#
# Epoch 00047: val_accuracy improved from 0.88356 to 0.89041, saving model to ./result\weights.h5
# Epoch 48/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.0570 - accuracy: 0.9186 - val_loss: 0.0945 - val_accuracy: 0.8630
#
# Epoch 00048: val_accuracy did not improve from 0.89041
# Epoch 49/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0529 - accuracy: 0.9121 - val_loss: 0.0888 - val_accuracy: 0.8767
#
# Epoch 00049: val_accuracy did not improve from 0.89041
# Epoch 50/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0502 - accuracy: 0.9316 - val_loss: 0.0935 - val_accuracy: 0.8630
#
# Epoch 00050: val_accuracy did not improve from 0.89041
# Epoch 51/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0531 - accuracy: 0.9121 - val_loss: 0.0867 - val_accuracy: 0.8562
#
# Epoch 00051: val_accuracy did not improve from 0.89041
# Epoch 52/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0521 - accuracy: 0.9251 - val_loss: 0.0878 - val_accuracy: 0.8630
#
# Epoch 00052: val_accuracy did not improve from 0.89041
# Epoch 53/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0476 - accuracy: 0.9218 - val_loss: 0.0915 - val_accuracy: 0.8767
#
# Epoch 00053: val_accuracy did not improve from 0.89041
# Epoch 54/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0488 - accuracy: 0.9186 - val_loss: 0.0907 - val_accuracy: 0.8699
#
# Epoch 00054: val_accuracy did not improve from 0.89041
# Epoch 55/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0402 - accuracy: 0.9479 - val_loss: 0.0862 - val_accuracy: 0.8699
#
# Epoch 00055: val_accuracy did not improve from 0.89041
# Epoch 56/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0444 - accuracy: 0.9283 - val_loss: 0.0862 - val_accuracy: 0.8904
#
# Epoch 00056: val_accuracy did not improve from 0.89041
# Epoch 57/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0433 - accuracy: 0.9283 - val_loss: 0.0864 - val_accuracy: 0.8836
#
# Epoch 00057: val_accuracy did not improve from 0.89041
# Epoch 58/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0422 - accuracy: 0.9316 - val_loss: 0.0878 - val_accuracy: 0.8836
#
# Epoch 00058: val_accuracy did not improve from 0.89041
# Epoch 59/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0438 - accuracy: 0.9414 - val_loss: 0.0874 - val_accuracy: 0.8767
#
# Epoch 00059: val_accuracy did not improve from 0.89041
# Epoch 60/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0413 - accuracy: 0.9414 - val_loss: 0.0872 - val_accuracy: 0.8767
#
# Epoch 00060: val_accuracy did not improve from 0.89041
# Epoch 61/100
# 10/10 [==============================] - 1s 147ms/step - loss: 0.0350 - accuracy: 0.9544 - val_loss: 0.0945 - val_accuracy: 0.8630
#
# Epoch 00061: val_accuracy did not improve from 0.89041
# Epoch 62/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.0362 - accuracy: 0.9414 - val_loss: 0.0890 - val_accuracy: 0.8767
#
# Epoch 00062: val_accuracy did not improve from 0.89041
# Epoch 63/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0373 - accuracy: 0.9544 - val_loss: 0.0889 - val_accuracy: 0.8767
#
# Epoch 00063: val_accuracy did not improve from 0.89041
# Epoch 64/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0389 - accuracy: 0.9446 - val_loss: 0.0950 - val_accuracy: 0.8630
#
# Epoch 00064: val_accuracy did not improve from 0.89041
# Epoch 65/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0358 - accuracy: 0.9544 - val_loss: 0.0953 - val_accuracy: 0.8767
#
# Epoch 00065: val_accuracy did not improve from 0.89041
# Epoch 66/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0390 - accuracy: 0.9479 - val_loss: 0.0885 - val_accuracy: 0.8630
#
# Epoch 00066: val_accuracy did not improve from 0.89041
# Epoch 67/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0394 - accuracy: 0.9511 - val_loss: 0.0923 - val_accuracy: 0.8562
#
# Epoch 00067: val_accuracy did not improve from 0.89041
# Epoch 68/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0342 - accuracy: 0.9446 - val_loss: 0.0992 - val_accuracy: 0.8630
#
# Epoch 00068: val_accuracy did not improve from 0.89041
# Epoch 69/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0336 - accuracy: 0.9544 - val_loss: 0.0919 - val_accuracy: 0.8562
#
# Epoch 00069: val_accuracy did not improve from 0.89041
# Epoch 70/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0331 - accuracy: 0.9479 - val_loss: 0.0908 - val_accuracy: 0.8630
#
# Epoch 00070: val_accuracy did not improve from 0.89041
# Epoch 71/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0286 - accuracy: 0.9609 - val_loss: 0.0912 - val_accuracy: 0.8699
#
# Epoch 00071: val_accuracy did not improve from 0.89041
# Epoch 72/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0263 - accuracy: 0.9674 - val_loss: 0.0974 - val_accuracy: 0.8630
#
# Epoch 00072: val_accuracy did not improve from 0.89041
# Epoch 73/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0280 - accuracy: 0.9609 - val_loss: 0.0995 - val_accuracy: 0.8630
#
# Epoch 00073: val_accuracy did not improve from 0.89041
# Epoch 74/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0278 - accuracy: 0.9577 - val_loss: 0.0916 - val_accuracy: 0.8699
#
# Epoch 00074: val_accuracy did not improve from 0.89041
# Epoch 75/100
# 10/10 [==============================] - 1s 147ms/step - loss: 0.0283 - accuracy: 0.9563 - val_loss: 0.0911 - val_accuracy: 0.8767
#
# Epoch 00075: val_accuracy did not improve from 0.89041
# Epoch 76/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0267 - accuracy: 0.9609 - val_loss: 0.0970 - val_accuracy: 0.8562
#
# Epoch 00076: val_accuracy did not improve from 0.89041
# Epoch 77/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0265 - accuracy: 0.9674 - val_loss: 0.0951 - val_accuracy: 0.8767
#
# Epoch 00077: val_accuracy did not improve from 0.89041
# Epoch 78/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0240 - accuracy: 0.9674 - val_loss: 0.0921 - val_accuracy: 0.8767
#
# Epoch 00078: val_accuracy did not improve from 0.89041
# Epoch 79/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0233 - accuracy: 0.9674 - val_loss: 0.1027 - val_accuracy: 0.8630
#
# Epoch 00079: val_accuracy did not improve from 0.89041
# Epoch 80/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0219 - accuracy: 0.9772 - val_loss: 0.0980 - val_accuracy: 0.8767
#
# Epoch 00080: val_accuracy did not improve from 0.89041
# Epoch 81/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0220 - accuracy: 0.9674 - val_loss: 0.0942 - val_accuracy: 0.8699
#
# Epoch 00081: val_accuracy did not improve from 0.89041
# Epoch 82/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0225 - accuracy: 0.9674 - val_loss: 0.0966 - val_accuracy: 0.8767
#
# Epoch 00082: val_accuracy did not improve from 0.89041
# Epoch 83/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0206 - accuracy: 0.9674 - val_loss: 0.0976 - val_accuracy: 0.8699
#
# Epoch 00083: val_accuracy did not improve from 0.89041
# Epoch 84/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0201 - accuracy: 0.9688 - val_loss: 0.1010 - val_accuracy: 0.8493
#
# Epoch 00084: val_accuracy did not improve from 0.89041
# Epoch 85/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0183 - accuracy: 0.9837 - val_loss: 0.0977 - val_accuracy: 0.8767
#
# Epoch 00085: val_accuracy did not improve from 0.89041
# Epoch 86/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0194 - accuracy: 0.9739 - val_loss: 0.0954 - val_accuracy: 0.8767
#
# Epoch 00086: val_accuracy did not improve from 0.89041
# Epoch 87/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0184 - accuracy: 0.9739 - val_loss: 0.0953 - val_accuracy: 0.8767
#
# Epoch 00087: val_accuracy did not improve from 0.89041
# Epoch 88/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0177 - accuracy: 0.9805 - val_loss: 0.1016 - val_accuracy: 0.8630
#
# Epoch 00088: val_accuracy did not improve from 0.89041
# Epoch 89/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0180 - accuracy: 0.9781 - val_loss: 0.0993 - val_accuracy: 0.8767
#
# Epoch 00089: val_accuracy did not improve from 0.89041
# Epoch 90/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0163 - accuracy: 0.9805 - val_loss: 0.0975 - val_accuracy: 0.8767
#
# Epoch 00090: val_accuracy did not improve from 0.89041
# Epoch 91/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0153 - accuracy: 0.9805 - val_loss: 0.0989 - val_accuracy: 0.8699
#
# Epoch 00091: val_accuracy did not improve from 0.89041
# Epoch 92/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0160 - accuracy: 0.9805 - val_loss: 0.0999 - val_accuracy: 0.8767
#
# Epoch 00092: val_accuracy did not improve from 0.89041
# Epoch 93/100
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0141 - accuracy: 0.9902 - val_loss: 0.0946 - val_accuracy: 0.8767
#
# Epoch 00093: val_accuracy did not improve from 0.89041
# Epoch 94/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0134 - accuracy: 0.9870 - val_loss: 0.0992 - val_accuracy: 0.8699
#
# Epoch 00094: val_accuracy did not improve from 0.89041
# Epoch 95/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.0139 - accuracy: 0.9902 - val_loss: 0.0995 - val_accuracy: 0.8767
#
# Epoch 00095: val_accuracy did not improve from 0.89041
# Epoch 96/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0124 - accuracy: 0.9902 - val_loss: 0.0972 - val_accuracy: 0.8699
#
# Epoch 00096: val_accuracy did not improve from 0.89041
# Epoch 97/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0132 - accuracy: 0.9902 - val_loss: 0.0992 - val_accuracy: 0.8699
#
# Epoch 00097: val_accuracy did not improve from 0.89041
# Epoch 98/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0124 - accuracy: 0.9902 - val_loss: 0.1002 - val_accuracy: 0.8767
#
# Epoch 00098: val_accuracy did not improve from 0.89041
# Epoch 99/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0120 - accuracy: 0.9870 - val_loss: 0.0958 - val_accuracy: 0.8699
#
# Epoch 00099: val_accuracy did not improve from 0.89041
# Epoch 100/100
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0117 - accuracy: 0.9902 - val_loss: 0.1031 - val_accuracy: 0.8493
#
# Epoch 00100: val_accuracy did not improve from 0.89041
# Best Validation Accuracy:0.8904109597206116
# *******Model Performance*************
# Test acc: 0.8904109589041096
# Precision:0.90625
# recall:0.925531914893617
# f1:0.9157894736842105
# AUC:0.8762274959083468
# Sensitivity:0.925531914893617
# specificity:0.8269230769230769

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=64
WIDTH=64
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [5],filters=[128],strides=[2])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(32, 64, 64, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 30, 30, 128)         9728
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 13, 13, 128)         409728
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 2704, 8)             0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 2704, 8)             0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               692224
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 1,111,680
# Trainable params: 1,111,680
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\gyani-desktop\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:367: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 10/10 [==============================] - 2s 102ms/step - loss: 0.5596 - accuracy: 0.4658 - val_loss: 0.2948 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64384, saving model to ./result\weights.h5
# Epoch 2/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3149 - accuracy: 0.6482 - val_loss: 0.3105 - val_accuracy: 0.6438
#
# Epoch 00002: val_accuracy did not improve from 0.64384
# Epoch 3/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2715 - accuracy: 0.6515 - val_loss: 0.2657 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.64384
# Epoch 4/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.2466 - accuracy: 0.6482 - val_loss: 0.2579 - val_accuracy: 0.6438
#
# Epoch 00004: val_accuracy did not improve from 0.64384
# Epoch 5/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.2369 - accuracy: 0.6482 - val_loss: 0.2499 - val_accuracy: 0.6438
#
# Epoch 00005: val_accuracy did not improve from 0.64384
# Epoch 6/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.2291 - accuracy: 0.6482 - val_loss: 0.2435 - val_accuracy: 0.6438
#
# Epoch 00006: val_accuracy did not improve from 0.64384
# Epoch 7/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.2285 - accuracy: 0.6482 - val_loss: 0.2367 - val_accuracy: 0.6438
#
# Epoch 00007: val_accuracy did not improve from 0.64384
# Epoch 8/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2239 - accuracy: 0.6482 - val_loss: 0.2293 - val_accuracy: 0.6438
#
# Epoch 00008: val_accuracy did not improve from 0.64384
# Epoch 9/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.2179 - accuracy: 0.6417 - val_loss: 0.2209 - val_accuracy: 0.6438
#
# Epoch 00009: val_accuracy did not improve from 0.64384
# Epoch 10/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2071 - accuracy: 0.6594 - val_loss: 0.2092 - val_accuracy: 0.6644
#
# Epoch 00010: val_accuracy improved from 0.64384 to 0.66438, saving model to ./result\weights.h5
# Epoch 11/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.1971 - accuracy: 0.6580 - val_loss: 0.2004 - val_accuracy: 0.6575
#
# Epoch 00011: val_accuracy did not improve from 0.66438
# Epoch 12/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.1824 - accuracy: 0.6840 - val_loss: 0.1875 - val_accuracy: 0.6644
#
# Epoch 00012: val_accuracy did not improve from 0.66438
# Epoch 13/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.1717 - accuracy: 0.7003 - val_loss: 0.1753 - val_accuracy: 0.6781
#
# Epoch 00013: val_accuracy improved from 0.66438 to 0.67808, saving model to ./result\weights.h5
# Epoch 14/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.1689 - accuracy: 0.7068 - val_loss: 0.1679 - val_accuracy: 0.6918
#
# Epoch 00014: val_accuracy improved from 0.67808 to 0.69178, saving model to ./result\weights.h5
# Epoch 15/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.1764 - accuracy: 0.7134 - val_loss: 0.1693 - val_accuracy: 0.6918
#
# Epoch 00015: val_accuracy did not improve from 0.69178
# Epoch 16/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.1728 - accuracy: 0.7036 - val_loss: 0.1676 - val_accuracy: 0.7055
#
# Epoch 00016: val_accuracy improved from 0.69178 to 0.70548, saving model to ./result\weights.h5
# Epoch 17/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1474 - accuracy: 0.7557 - val_loss: 0.1524 - val_accuracy: 0.7603
#
# Epoch 00017: val_accuracy improved from 0.70548 to 0.76027, saving model to ./result\weights.h5
# Epoch 18/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1423 - accuracy: 0.7557 - val_loss: 0.1493 - val_accuracy: 0.7260
#
# Epoch 00018: val_accuracy did not improve from 0.76027
# Epoch 19/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1354 - accuracy: 0.7785 - val_loss: 0.1436 - val_accuracy: 0.7397
#
# Epoch 00019: val_accuracy did not improve from 0.76027
# Epoch 20/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1373 - accuracy: 0.7622 - val_loss: 0.1331 - val_accuracy: 0.8082
#
# Epoch 00020: val_accuracy improved from 0.76027 to 0.80822, saving model to ./result\weights.h5
# Epoch 21/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1300 - accuracy: 0.7687 - val_loss: 0.1328 - val_accuracy: 0.7945
#
# Epoch 00021: val_accuracy did not improve from 0.80822
# Epoch 22/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1182 - accuracy: 0.7906 - val_loss: 0.1239 - val_accuracy: 0.8219
#
# Epoch 00022: val_accuracy improved from 0.80822 to 0.82192, saving model to ./result\weights.h5
# Epoch 23/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1183 - accuracy: 0.7818 - val_loss: 0.1227 - val_accuracy: 0.8082
#
# Epoch 00023: val_accuracy did not improve from 0.82192
# Epoch 24/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1143 - accuracy: 0.7980 - val_loss: 0.1211 - val_accuracy: 0.8219
#
# Epoch 00024: val_accuracy did not improve from 0.82192
# Epoch 25/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1099 - accuracy: 0.8176 - val_loss: 0.1181 - val_accuracy: 0.8014
#
# Epoch 00025: val_accuracy did not improve from 0.82192
# Epoch 26/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.1049 - accuracy: 0.8046 - val_loss: 0.1149 - val_accuracy: 0.8288
#
# Epoch 00026: val_accuracy improved from 0.82192 to 0.82877, saving model to ./result\weights.h5
# Epoch 27/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1045 - accuracy: 0.8241 - val_loss: 0.1149 - val_accuracy: 0.8151
#
# Epoch 00027: val_accuracy did not improve from 0.82877
# Epoch 28/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1070 - accuracy: 0.8313 - val_loss: 0.1098 - val_accuracy: 0.8425
#
# Epoch 00028: val_accuracy improved from 0.82877 to 0.84247, saving model to ./result\weights.h5
# Epoch 29/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1162 - accuracy: 0.8208 - val_loss: 0.1433 - val_accuracy: 0.7671
#
# Epoch 00029: val_accuracy did not improve from 0.84247
# Epoch 30/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1089 - accuracy: 0.8404 - val_loss: 0.1183 - val_accuracy: 0.8219
#
# Epoch 00030: val_accuracy did not improve from 0.84247
# Epoch 31/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1043 - accuracy: 0.8469 - val_loss: 0.1118 - val_accuracy: 0.8630
#
# Epoch 00031: val_accuracy improved from 0.84247 to 0.86301, saving model to ./result\weights.h5
# Epoch 32/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0968 - accuracy: 0.8371 - val_loss: 0.1046 - val_accuracy: 0.8767
#
# Epoch 00032: val_accuracy improved from 0.86301 to 0.87671, saving model to ./result\weights.h5
# Epoch 33/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0913 - accuracy: 0.8534 - val_loss: 0.1038 - val_accuracy: 0.8767
#
# Epoch 00033: val_accuracy did not improve from 0.87671
# Epoch 34/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0859 - accuracy: 0.8860 - val_loss: 0.1016 - val_accuracy: 0.8836
#
# Epoch 00034: val_accuracy improved from 0.87671 to 0.88356, saving model to ./result\weights.h5
# Epoch 35/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0888 - accuracy: 0.8795 - val_loss: 0.1048 - val_accuracy: 0.8836
#
# Epoch 00035: val_accuracy did not improve from 0.88356
# Epoch 36/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0812 - accuracy: 0.8893 - val_loss: 0.1032 - val_accuracy: 0.8699
#
# Epoch 00036: val_accuracy did not improve from 0.88356
# Epoch 37/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0950 - accuracy: 0.8274 - val_loss: 0.0988 - val_accuracy: 0.8699
#
# Epoch 00037: val_accuracy did not improve from 0.88356
# Epoch 38/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0848 - accuracy: 0.8860 - val_loss: 0.1003 - val_accuracy: 0.8904
#
# Epoch 00038: val_accuracy improved from 0.88356 to 0.89041, saving model to ./result\weights.h5
# Epoch 39/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0816 - accuracy: 0.8958 - val_loss: 0.1086 - val_accuracy: 0.9041
#
# Epoch 00039: val_accuracy improved from 0.89041 to 0.90411, saving model to ./result\weights.h5
# Epoch 40/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0884 - accuracy: 0.8599 - val_loss: 0.1011 - val_accuracy: 0.9041
#
# Epoch 00040: val_accuracy did not improve from 0.90411
# Epoch 41/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0881 - accuracy: 0.8632 - val_loss: 0.0973 - val_accuracy: 0.8767
#
# Epoch 00041: val_accuracy did not improve from 0.90411
# Epoch 42/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0855 - accuracy: 0.8762 - val_loss: 0.0976 - val_accuracy: 0.8699
#
# Epoch 00042: val_accuracy did not improve from 0.90411
# Epoch 43/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0766 - accuracy: 0.8893 - val_loss: 0.1056 - val_accuracy: 0.8973
#
# Epoch 00043: val_accuracy did not improve from 0.90411
# Epoch 44/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0825 - accuracy: 0.8664 - val_loss: 0.0943 - val_accuracy: 0.8904
#
# Epoch 00044: val_accuracy did not improve from 0.90411
# Epoch 45/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0838 - accuracy: 0.8795 - val_loss: 0.0945 - val_accuracy: 0.8699
#
# Epoch 00045: val_accuracy did not improve from 0.90411
# Epoch 46/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0798 - accuracy: 0.8860 - val_loss: 0.0920 - val_accuracy: 0.8699
#
# Epoch 00046: val_accuracy did not improve from 0.90411
# Epoch 47/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0770 - accuracy: 0.8925 - val_loss: 0.0913 - val_accuracy: 0.8973
#
# Epoch 00047: val_accuracy did not improve from 0.90411
# Epoch 48/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0815 - accuracy: 0.8795 - val_loss: 0.1011 - val_accuracy: 0.8904
#
# Epoch 00048: val_accuracy did not improve from 0.90411
# Epoch 49/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0781 - accuracy: 0.8893 - val_loss: 0.0958 - val_accuracy: 0.8973
#
# Epoch 00049: val_accuracy did not improve from 0.90411
# Epoch 50/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0750 - accuracy: 0.8925 - val_loss: 0.1128 - val_accuracy: 0.8562
#
# Epoch 00050: val_accuracy did not improve from 0.90411
# Epoch 51/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0841 - accuracy: 0.8697 - val_loss: 0.0994 - val_accuracy: 0.8425
#
# Epoch 00051: val_accuracy did not improve from 0.90411
# Epoch 52/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0789 - accuracy: 0.8893 - val_loss: 0.0982 - val_accuracy: 0.8836
#
# Epoch 00052: val_accuracy did not improve from 0.90411
# Epoch 53/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0785 - accuracy: 0.9055 - val_loss: 0.0938 - val_accuracy: 0.8904
#
# Epoch 00053: val_accuracy did not improve from 0.90411
# Epoch 54/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0779 - accuracy: 0.8958 - val_loss: 0.0995 - val_accuracy: 0.8904
#
# Epoch 00054: val_accuracy did not improve from 0.90411
# Epoch 55/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0720 - accuracy: 0.9121 - val_loss: 0.0943 - val_accuracy: 0.9041
#
# Epoch 00055: val_accuracy did not improve from 0.90411
# Epoch 56/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0716 - accuracy: 0.9023 - val_loss: 0.0894 - val_accuracy: 0.8904
#
# Epoch 00056: val_accuracy did not improve from 0.90411
# Epoch 57/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0705 - accuracy: 0.9121 - val_loss: 0.0897 - val_accuracy: 0.8973
#
# Epoch 00057: val_accuracy did not improve from 0.90411
# Epoch 58/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0713 - accuracy: 0.9023 - val_loss: 0.0955 - val_accuracy: 0.8904
#
# Epoch 00058: val_accuracy did not improve from 0.90411
# Epoch 59/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0759 - accuracy: 0.8958 - val_loss: 0.0954 - val_accuracy: 0.8699
#
# Epoch 00059: val_accuracy did not improve from 0.90411
# Epoch 60/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0755 - accuracy: 0.8990 - val_loss: 0.0898 - val_accuracy: 0.8973
#
# Epoch 00060: val_accuracy did not improve from 0.90411
# Epoch 61/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0648 - accuracy: 0.9055 - val_loss: 0.0978 - val_accuracy: 0.8904
#
# Epoch 00061: val_accuracy did not improve from 0.90411
# Epoch 62/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0648 - accuracy: 0.9153 - val_loss: 0.0907 - val_accuracy: 0.8904
#
# Epoch 00062: val_accuracy did not improve from 0.90411
# Epoch 63/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0683 - accuracy: 0.9153 - val_loss: 0.0908 - val_accuracy: 0.8973
#
# Epoch 00063: val_accuracy did not improve from 0.90411
# Epoch 64/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0708 - accuracy: 0.8893 - val_loss: 0.1168 - val_accuracy: 0.8356
#
# Epoch 00064: val_accuracy did not improve from 0.90411
# Epoch 65/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0759 - accuracy: 0.8664 - val_loss: 0.0947 - val_accuracy: 0.8630
#
# Epoch 00065: val_accuracy did not improve from 0.90411
# Epoch 66/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0724 - accuracy: 0.8990 - val_loss: 0.0956 - val_accuracy: 0.8699
#
# Epoch 00066: val_accuracy did not improve from 0.90411
# Epoch 67/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0667 - accuracy: 0.8925 - val_loss: 0.0998 - val_accuracy: 0.8767
#
# Epoch 00067: val_accuracy did not improve from 0.90411
# Epoch 68/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0611 - accuracy: 0.9186 - val_loss: 0.0968 - val_accuracy: 0.8699
#
# Epoch 00068: val_accuracy did not improve from 0.90411
# Epoch 69/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0626 - accuracy: 0.9218 - val_loss: 0.0973 - val_accuracy: 0.8904
#
# Epoch 00069: val_accuracy did not improve from 0.90411
# Epoch 70/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0659 - accuracy: 0.8990 - val_loss: 0.0905 - val_accuracy: 0.8767
#
# Epoch 00070: val_accuracy did not improve from 0.90411
# Epoch 71/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0608 - accuracy: 0.9218 - val_loss: 0.0917 - val_accuracy: 0.8904
#
# Epoch 00071: val_accuracy did not improve from 0.90411
# Epoch 72/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0597 - accuracy: 0.9153 - val_loss: 0.0931 - val_accuracy: 0.8767
#
# Epoch 00072: val_accuracy did not improve from 0.90411
# Epoch 73/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0622 - accuracy: 0.9186 - val_loss: 0.1093 - val_accuracy: 0.8425
#
# Epoch 00073: val_accuracy did not improve from 0.90411
# Epoch 74/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0575 - accuracy: 0.9251 - val_loss: 0.0910 - val_accuracy: 0.8904
#
# Epoch 00074: val_accuracy did not improve from 0.90411
# Epoch 75/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0622 - accuracy: 0.9125 - val_loss: 0.0934 - val_accuracy: 0.8767
#
# Epoch 00075: val_accuracy did not improve from 0.90411
# Epoch 76/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0606 - accuracy: 0.9088 - val_loss: 0.0945 - val_accuracy: 0.8767
#
# Epoch 00076: val_accuracy did not improve from 0.90411
# Epoch 77/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0626 - accuracy: 0.9121 - val_loss: 0.0949 - val_accuracy: 0.8767
#
# Epoch 00077: val_accuracy did not improve from 0.90411
# Epoch 78/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0599 - accuracy: 0.9121 - val_loss: 0.0930 - val_accuracy: 0.8904
#
# Epoch 00078: val_accuracy did not improve from 0.90411
# Epoch 79/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0568 - accuracy: 0.9251 - val_loss: 0.1008 - val_accuracy: 0.8699
#
# Epoch 00079: val_accuracy did not improve from 0.90411
# Epoch 80/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0554 - accuracy: 0.9316 - val_loss: 0.0937 - val_accuracy: 0.8836
#
# Epoch 00080: val_accuracy did not improve from 0.90411
# Epoch 81/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0595 - accuracy: 0.9283 - val_loss: 0.0978 - val_accuracy: 0.8630
#
# Epoch 00081: val_accuracy did not improve from 0.90411
# Epoch 82/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0604 - accuracy: 0.9186 - val_loss: 0.1051 - val_accuracy: 0.8699
#
# Epoch 00082: val_accuracy did not improve from 0.90411
# Epoch 83/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0550 - accuracy: 0.9218 - val_loss: 0.0949 - val_accuracy: 0.8767
#
# Epoch 00083: val_accuracy did not improve from 0.90411
# Epoch 84/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0574 - accuracy: 0.9219 - val_loss: 0.0997 - val_accuracy: 0.8836
#
# Epoch 00084: val_accuracy did not improve from 0.90411
# Epoch 85/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0561 - accuracy: 0.9283 - val_loss: 0.1085 - val_accuracy: 0.8562
#
# Epoch 00085: val_accuracy did not improve from 0.90411
# Epoch 86/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0544 - accuracy: 0.9251 - val_loss: 0.0943 - val_accuracy: 0.8904
#
# Epoch 00086: val_accuracy did not improve from 0.90411
# Epoch 87/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0526 - accuracy: 0.9349 - val_loss: 0.0964 - val_accuracy: 0.8630
#
# Epoch 00087: val_accuracy did not improve from 0.90411
# Epoch 88/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0528 - accuracy: 0.9283 - val_loss: 0.0939 - val_accuracy: 0.8767
#
# Epoch 00088: val_accuracy did not improve from 0.90411
# Epoch 89/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0517 - accuracy: 0.9312 - val_loss: 0.0967 - val_accuracy: 0.8767
#
# Epoch 00089: val_accuracy did not improve from 0.90411
# Epoch 90/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0513 - accuracy: 0.9349 - val_loss: 0.0991 - val_accuracy: 0.8767
#
# Epoch 00090: val_accuracy did not improve from 0.90411
# Epoch 91/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0489 - accuracy: 0.9446 - val_loss: 0.0957 - val_accuracy: 0.8699
#
# Epoch 00091: val_accuracy did not improve from 0.90411
# Epoch 92/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0533 - accuracy: 0.9446 - val_loss: 0.0948 - val_accuracy: 0.8904
#
# Epoch 00092: val_accuracy did not improve from 0.90411
# Epoch 93/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0519 - accuracy: 0.9251 - val_loss: 0.0956 - val_accuracy: 0.8767
#
# Epoch 00093: val_accuracy did not improve from 0.90411
# Epoch 94/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0485 - accuracy: 0.9381 - val_loss: 0.0986 - val_accuracy: 0.8767
#
# Epoch 00094: val_accuracy did not improve from 0.90411
# Epoch 95/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0516 - accuracy: 0.9283 - val_loss: 0.0960 - val_accuracy: 0.8699
#
# Epoch 00095: val_accuracy did not improve from 0.90411
# Epoch 96/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0476 - accuracy: 0.9544 - val_loss: 0.1020 - val_accuracy: 0.8699
#
# Epoch 00096: val_accuracy did not improve from 0.90411
# Epoch 97/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0507 - accuracy: 0.9414 - val_loss: 0.1076 - val_accuracy: 0.8699
#
# Epoch 00097: val_accuracy did not improve from 0.90411
# Epoch 98/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0487 - accuracy: 0.9511 - val_loss: 0.0968 - val_accuracy: 0.8699
#
# Epoch 00098: val_accuracy did not improve from 0.90411
# Epoch 99/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0476 - accuracy: 0.9446 - val_loss: 0.0930 - val_accuracy: 0.8767
#
# Epoch 00099: val_accuracy did not improve from 0.90411
# Epoch 100/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0450 - accuracy: 0.9446 - val_loss: 0.0985 - val_accuracy: 0.8699
#
# Epoch 00100: val_accuracy did not improve from 0.90411
# Best Validation Accuracy:0.9041095972061157
# *******Model Performance*************
# Test acc: 0.9041095890410958
# Precision:0.9081632653061225
# recall:0.9468085106382979
# f1:0.9270833333333334
# AUC:0.8868657937806873
# Sensitivity:0.9468085106382979
# specificity:0.8269230769230769

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=64
WIDTH=64
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [3],filters=[128],strides=[1])
# Out:
# Namespace(augmentation=False, batch_size=32, debug=False, digit=5, epochs=15, lam_recon=0.392, lr=0.0001, lr_decay=1, routings=1, save_dir='./result', shift_fraction=0.1, testing=False, weights=None)
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(32, 64, 64, 3)]         0
# _________________________________________________________________
# conv0 (Conv2D)               (32, 62, 62, 128)         3584
# _________________________________________________________________
# primarycap_conv2d (Conv2D)   (32, 60, 60, 128)         147584
# _________________________________________________________________
# primarycap_reshape (Reshape) (32, 57600, 8)            0
# _________________________________________________________________
# primarycap_squash (Lambda)   (32, 57600, 8)            0
# _________________________________________________________________
# digitcaps (CapsuleLayer)     (32, 2, 16)               14745600
# _________________________________________________________________
# capsnet (Length)             (32, 2)                   0
# =================================================================
# Total params: 14,896,768
# Trainable params: 14,896,768
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 44' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000054?line=5'>6</a> WIDTH=64
#       <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000054?line=6'>7</a> data = get_rim_one_dl()
# ----> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000054?line=7'>8</a> get_model_train_test(data,args,kernels= [3],filters=[128],strides=[1])
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\autograph\impl\api.py:649, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=646'>647</a> def wrapper(*args, **kwargs):
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=647'>648</a>   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=648'>649</a>     return func(*args, **kwargs)
#
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 19' in get_model_train_test(data, args, n_channels, dim_capsule, kernels, filters, strides, multi_level_feature_extraction)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=22'>23</a> model.summary()
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=23'>24</a> # Train the model
# ---> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=24'>25</a> trained_model = train(model=model, data=((x_train, y_train), (x_test, y_test)), args=args)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=25'>26</a> #Load the weight where accuracy was maximum
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000018?line=26'>27</a> trained_model.load_weights(f'./result/weights.h5')
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\autograph\impl\api.py:649, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=646'>647</a> def wrapper(*args, **kwargs):
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=647'>648</a>   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=648'>649</a>     return func(*args, **kwargs)
#
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 15' in train(model, data, args)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=25'>26</a> val_image_generator = ImageDataGenerator()
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=26'>27</a> val_data_generator = val_image_generator.flow(x_test,y_test,batch_size = args.batch_size)
# ---> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=28'>29</a> history = model.fit(train_data_generator,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=29'>30</a>           steps_per_epoch=int(y_train.shape[0] / args.batch_size),
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=30'>31</a>           epochs=args.epochs,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=31'>32</a>           validation_data=val_data_generator, batch_size=args.batch_size,
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=32'>33</a>           callbacks=[checkpoint])
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=34'>35</a> index = history.history["val_accuracy"].index(max(history.history["val_accuracy"]))
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000014?line=35'>36</a> best_val_accuracy = history.history["val_accuracy"][index]
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\training.py:1189, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1181'>1182</a> with trace.Trace(
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1182'>1183</a>     'train',
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1183'>1184</a>     epoch_num=epoch,
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1184'>1185</a>     step_num=step,
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1185'>1186</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1186'>1187</a>     _r=1):
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1187'>1188</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1188'>1189</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1189'>1190</a>   if data_handler.should_sync:
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=1190'>1191</a>     context.async_wait()
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\training.py:859, in Model.make_train_function.<locals>.train_function(iterator)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=856'>857</a> def train_function(iterator):
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=857'>858</a>   """Runs a training execution with one step."""
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=858'>859</a>   return step_function(self, iterator)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\training.py:849, in Model.make_train_function.<locals>.step_function(model, iterator)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=845'>846</a>   return outputs
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=847'>848</a> data = next(iterator)
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=848'>849</a> outputs = model.distribute_strategy.run(run_step, args=(data,))
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=849'>850</a> outputs = reduce_per_replica(
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=850'>851</a>     outputs, self.distribute_strategy, reduction='first')
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=851'>852</a> write_scalar_summaries(outputs, step=model._train_counter)  # pylint: disable=protected-access
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1316, in StrategyBase.run(***failed resolving arguments***)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=1310'>1311</a> with self.scope():
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=1311'>1312</a>   # tf.distribute supports Eager functions, so AutoGraph should not be
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=1312'>1313</a>   # applied when the caller is also in Eager mode.
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=1313'>1314</a>   fn = autograph.tf_convert(
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=1314'>1315</a>       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=1315'>1316</a>   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2892, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=2889'>2890</a>   kwargs = {}
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=2890'>2891</a> with self._container_strategy().scope():
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=2891'>2892</a>   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3695, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=3692'>3693</a> def _call_for_each_replica(self, fn, args, kwargs):
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=3693'>3694</a>   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/distribute/distribute_lib.py?line=3694'>3695</a>     return fn(*args, **kwargs)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\autograph\impl\api.py:649, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=646'>647</a> def wrapper(*args, **kwargs):
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=647'>648</a>   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=648'>649</a>     return func(*args, **kwargs)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\training.py:842, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=840'>841</a> def run_step(data):
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=841'>842</a>   outputs = model.train_step(data)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=842'>843</a>   # Ensure counter is updated only if `train_step` succeeds.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=843'>844</a>   with ops.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\training.py:799, in Model.train_step(self, data)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=796'>797</a> # Run forward pass.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=797'>798</a> with backprop.GradientTape() as tape:
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=798'>799</a>   y_pred = self(x, training=True)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=799'>800</a>   loss = self.compiled_loss(
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=800'>801</a>       y, y_pred, sample_weight, regularization_losses=self.losses)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/training.py?line=801'>802</a> # Run backwards pass.
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1044, in Layer.__call__(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1039'>1040</a>   inputs = self._maybe_cast_inputs(inputs, input_list)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1041'>1042</a> with autocast_variable.enable_auto_cast_variables(
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1042'>1043</a>     self._compute_dtype_object):
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1043'>1044</a>   outputs = call_fn(inputs, *args, **kwargs)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1045'>1046</a> if self._activity_regularizer:
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1046'>1047</a>   self._handle_activity_regularization(inputs, outputs)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\functional.py:419, in Functional.call(self, inputs, training, mask)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=399'>400</a> @doc_controls.do_not_doc_inheritable
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=400'>401</a> def call(self, inputs, training=None, mask=None):
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=401'>402</a>   """Calls the model on new inputs.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=402'>403</a>
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=403'>404</a>   In this case `call` just reapplies
#    (...)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=416'>417</a>       a list of tensors if there are more than one outputs.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=417'>418</a>   """
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=418'>419</a>   return self._run_internal_graph(
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=419'>420</a>       inputs, training=training, mask=mask)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\functional.py:555, in Functional._run_internal_graph(self, inputs, training, mask)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=551'>552</a>   continue  # Node is not computable, try skipping.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=553'>554</a> args, kwargs = node.map_arguments(tensor_dict)
# --> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=554'>555</a> outputs = node.layer(*args, **kwargs)
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=556'>557</a> # Update tensor_dict.
#     <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=557'>558</a> for x_id, y in zip(node.flat_output_ids, nest.flatten(outputs)):
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1044, in Layer.__call__(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1039'>1040</a>   inputs = self._maybe_cast_inputs(inputs, input_list)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1041'>1042</a> with autocast_variable.enable_auto_cast_variables(
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1042'>1043</a>     self._compute_dtype_object):
# -> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1043'>1044</a>   outputs = call_fn(inputs, *args, **kwargs)
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1045'>1046</a> if self._activity_regularizer:
#    <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/keras/engine/base_layer.py?line=1046'>1047</a>   self._handle_activity_regularization(inputs, outputs)
#
# c:\gyani\Projects_MS\code\tensorflow\capsNet\capsnetWithoutDeocder_VaryingFilter.ipynb Cell 10' in CapsuleLayer.call(self, inputs, training)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=66'>67</a> inputs_expand = tf.expand_dims(tf.expand_dims(inputs, 1), -1)
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=68'>69</a> # Replicate num_capsule dimension to prepare being multiplied by W
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=69'>70</a> # inputs_tiled.shape=[None, num_capsule, input_num_capsule, input_dim_capsule, 1]
# ---> <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=70'>71</a> inputs_tiled = tf.tile(inputs_expand, [1, self.num_capsule, 1, 1, 1])
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=72'>73</a> # Compute `inputs * W` by scanning inputs_tiled on dimension 0.
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=73'>74</a> # W.shape=[num_capsule, input_num_capsule, dim_capsule, input_dim_capsule]
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=74'>75</a> # x.shape=[num_capsule, input_num_capsule, input_dim_capsule, 1]
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=75'>76</a> # Regard the first two dimensions as `batch` dimension, then
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=76'>77</a> # matmul(W, x): [..., dim_capsule, input_dim_capsule] x [..., input_dim_capsule, 1] -> [..., dim_capsule, 1].
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=77'>78</a> # inputs_hat.shape = [None, num_capsule, input_num_capsule, dim_capsule]
#      <a href='vscode-notebook-cell:/c%3A/gyani/Projects_MS/code/tensorflow/capsNet/capsnetWithoutDeocder_VaryingFilter.ipynb#ch0000009?line=78'>79</a> inputs_hat = tf.squeeze(tf.map_fn(lambda x: tf.matmul(self.W, x), elems=inputs_tiled))
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:11726, in tile(input, multiples, name)
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11723'>11724</a>   if _result is not NotImplemented:
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11724'>11725</a>     return _result
# > <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11725'>11726</a>   return tile_eager_fallback(
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11726'>11727</a>       input, multiples, name=name, ctx=_ctx)
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11727'>11728</a> except _core._SymbolicException:
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11728'>11729</a>   pass  # Add nodes to the TensorFlow graph.
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:11772, in tile_eager_fallback(input, multiples, name, ctx)
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11769'>11770</a> _inputs_flat = [input, multiples]
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11770'>11771</a> _attrs = ("T", _attr_T, "Tmultiples", _attr_Tmultiples)
# > <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11771'>11772</a> _result = _execute.execute(b"Tile", 1, inputs=_inputs_flat, attrs=_attrs,
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11772'>11773</a>                            ctx=ctx, name=name)
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11773'>11774</a> if _execute.must_record_gradient():
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11774'>11775</a>   _execute.record_gradient(
#   <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=11775'>11776</a>       "Tile", _inputs_flat, _attrs, _result)
#
# File ~\.conda\envs\lab3\lib\site-packages\tensorflow\python\eager\execute.py:58, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> try:
#      <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/eager/execute.py?line=57'>58</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/eager/execute.py?line=58'>59</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/eager/execute.py?line=59'>60</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/Users/gyani-desktop/.conda/envs/lab3/lib/site-packages/tensorflow/python/eager/execute.py?line=60'>61</a>   if name is not None:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[32,2,57600,8,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Tile]

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
HEIGHT=128
WIDTH=128
data = get_rim_one_dl()
get_model_train_test(data,args,kernels= [5],filters=[128],strides=[1])

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 50
args.routings = 3
data = get_rim_one_dl()
get_model_train_test(data,args)

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 50
args.routings = 1
data = get_rim_one_dl()
get_model_train_test(data,args)

# %%
HEIGHT= 32
WIDTH = 32

# %% [markdown]
# # RIMONE V2

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 8
data = get_rim_one_db_r2()
get_model_train_test(data,args)

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 3
data = get_rim_one_db_r2()
get_model_train_test(data,args)

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
data = get_rim_one_db_r2()
get_model_train_test(data,args)

# %% [markdown]
# # ACRIMA

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 8
data = get_acrima_dataset()
get_model_train_test(data,args)

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 3
data = get_acrima_dataset()
get_model_train_test(data,args)

# %%
args = get_arguments()
args.batch_size = 32
args.epochs = 100
args.routings = 1
data = get_acrima_dataset()
get_model_train_test(data,args)
